# %%
import torch
import random
import pandas as pd
import numpy as np
import joblib
from pathlib import Path
import os
from torch import nn

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import cv2

import json
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, TensorDataset

from sklearn.utils.class_weight import compute_class_weight

from sklearn.preprocessing import LabelEncoder, MinMaxScaler, OneHotEncoder, StandardScaler

# Local application/library imports
from utils import load_search_space

import optuna

from sklearn.metrics import (
    RocCurveDisplay, PrecisionRecallDisplay,
    ConfusionMatrixDisplay, roc_auc_score, average_precision_score
)

# %% [markdown]
# ## DATASET

# %%
SEED = 64

# Set random seeds
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
# Dataset Info
# adult_income_cleaned, framingham_cleaned, preprocessed_heloc, diabetes
dataset_name = 'boston'        
dataset_subpath = 'Regression/boston'       
task_type = 'Regression'

# %%
df = pd.read_csv(f"./data/{dataset_subpath}/{dataset_name}.csv")

# %%
df.shape
# Out:
# (506, 14)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ## LOAD AND PREPROCESS

# %%
def prepare_target_tensor(y, task):
    task = task.lower()
    if isinstance(y, pd.Series):
        y = y.to_numpy()
    elif isinstance(y, list):
        y = np.array(y)
        
    if task == "regression" or task == "binary":
        return torch.as_tensor(y, dtype=torch.float32).reshape(-1, 1)
    elif task == "multiclass":
        return torch.as_tensor(y, dtype=torch.long)
    else:
        raise ValueError(f"Unsupported task type: {task}")

# %%
def load_and_preprocess_data(df, dataset_name, images_folder, 
                             problem_type, task_type, seed=42, batch_size=32, device='cpu'):
    task_type = task_type.lower()

    # Load config
    with open(f"./configs/preprocess/{dataset_name}.json") as f:
        config = json.load(f)

    categorical_cols = config["categorical_cols"]
    numerical_cols = config["numerical_cols"]
    encoding = config["encoding"]

    # Extract features and target
    X = df[numerical_cols + categorical_cols].copy()
    y = df.iloc[:, -1].copy()

    # Encode target if needed
    le = None
    if encoding.get("target") == "label":
        le = LabelEncoder()
        y = le.fit_transform(y)
        label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    else:
        label_mapping = None

    # Split raw data before transformation
    if task_type == "regression":
        # For regression, we can use a simple split
        X_train_raw, X_temp_raw, y_train, y_temp = train_test_split(
            X, y, test_size=0.3, random_state=seed
        )
        X_val_raw, X_test_raw, y_val, y_test = train_test_split(
            X_temp_raw, y_temp, test_size=0.5, random_state=seed
        )
    else:
        # For classification, we need stratified splits
        X_train_raw, X_temp_raw, y_train, y_temp = train_test_split(
            X, y, test_size=0.3, random_state=seed, stratify=y
        )
        X_val_raw, X_test_raw, y_val, y_test = train_test_split(
            X_temp_raw, y_temp, test_size=0.5, random_state=seed, stratify=y_temp
        )

    # Compute class weights for classification
    class_weight = None
    if task_type in ["binary", "multiclass"]:
        # Compute raw weights
        class_weight_values = compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y=y_train)
        classes_sorted = np.sort(np.unique(y_train))
        
        if task_type == "binary":
            # Compute pos_weight = weight for class 1 / weight for class 0
            weight_dict = dict(zip(classes_sorted, class_weight_values))
            pos_weight = weight_dict[1] / weight_dict[0]
            class_weight = torch.tensor(pos_weight, dtype=torch.float32).to(device)
            print(f"Binary pos_weight (for BCEWithLogitsLoss): {class_weight.item()}")

        elif task_type == "multiclass":
            class_weight = torch.tensor(class_weight_values, dtype=torch.float32).to(device)
            print(f"Multiclass class weights (for CrossEntropyLoss): {class_weight.tolist()}")

    # Transform numerical and categorical features
    transformers = []

    if encoding["numerical_features"] == "minmax":
        transformers.append(("num", MinMaxScaler(), numerical_cols))
    elif encoding["numerical_features"] == "standard":
        transformers.append(("num", StandardScaler(), numerical_cols))

    if categorical_cols and encoding["categorical_features"] == "onehot":
        transformers.append(("cat", OneHotEncoder(sparse_output=False, handle_unknown="ignore"), categorical_cols))

    if transformers:
        preprocessor = ColumnTransformer(transformers=transformers)
        X_train = preprocessor.fit_transform(X_train_raw)
        X_val = preprocessor.transform(X_val_raw)
        X_test = preprocessor.transform(X_test_raw)

        # Recover transformed column names
        if "cat" in preprocessor.named_transformers_:
            cat_feature_names = preprocessor.named_transformers_["cat"].get_feature_names_out(categorical_cols)
            all_feature_names = numerical_cols + list(cat_feature_names)
        else:
            all_feature_names = numerical_cols + categorical_cols

        X_train_num = pd.DataFrame(X_train, columns=all_feature_names, index=X_train_raw.index)
        X_val_num = pd.DataFrame(X_val, columns=all_feature_names, index=X_val_raw.index)
        X_test_num = pd.DataFrame(X_test, columns=all_feature_names, index=X_test_raw.index)
    else:
        all_feature_names = numerical_cols + categorical_cols  # or keep original order
        X_train_num = pd.DataFrame(X_train_raw, columns=all_feature_names, index=X_train_raw.index)
        X_val_num = pd.DataFrame(X_val_raw, columns=all_feature_names, index=X_val_raw.index)
        X_test_num = pd.DataFrame(X_test_raw, columns=all_feature_names, index=X_test_raw.index)


    print(f"Shapes — Train: {X_train_num.shape}, Val: {X_val_num.shape}, Test: {X_test_num.shape}")
    print(f"Numerical features: {len(numerical_cols)} — {numerical_cols}")
    print(f"Categorical features: {len(categorical_cols)} — {categorical_cols}")
    print(f"Total features: {X_train_num.shape[1]}")
    if label_mapping:
        print(f"Target label mapping: {label_mapping}")

    # -------------------------------
    # Image generation
    # -------------------------------
    ### X_train
    img_paths = os.path.join(f'{images_folder}/train',problem_type+".csv")

    print(img_paths)
    
    imgs = pd.read_csv(img_paths)
    
    # Update image paths
    imgs["images"] = images_folder + "/train/" + imgs["images"]

    # Image data
    X_train_img = np.array([cv2.cvtColor(cv2.imread(img), cv2.COLOR_BGR2RGB) for img in imgs["images"]])
        
    ### X_val
    img_paths = os.path.join(f'{images_folder}/val',problem_type+".csv")

    print(img_paths)
    
    imgs = pd.read_csv(img_paths)

    # Update image paths
    imgs["images"] = images_folder + "/val/" + imgs["images"]

    # Image data
    X_val_img = np.array([cv2.cvtColor(cv2.imread(img), cv2.COLOR_BGR2RGB) for img in imgs["images"]])

    ### test

    img_paths = os.path.join(f'{images_folder}/test',problem_type+".csv")

    print(img_paths)
    
    imgs = pd.read_csv(img_paths)

    # Update image paths
    imgs["images"] = images_folder + "/test/" + imgs["images"]

    # Image data
    X_test_img = np.array([cv2.cvtColor(cv2.imread(img), cv2.COLOR_BGR2RGB) for img in imgs["images"]])
    

    attributes = len(X_train_num.columns)
    height, width, channels = X_train_img[0].shape
    imgs_shape = (channels, height, width)

    print("Images shape: ", imgs_shape)
    print("Attributes: ", attributes)
    # Convert data to PyTorch tensors
    X_train_num_tensor = torch.as_tensor(X_train_num.values, dtype=torch.float32)
    X_val_num_tensor = torch.as_tensor(X_val_num.values, dtype=torch.float32)
    X_test_num_tensor = torch.as_tensor(X_test_num.values, dtype=torch.float32)
    X_train_img_tensor = torch.as_tensor(X_train_img, dtype=torch.float32).permute(0, 3, 1, 2)
    X_val_img_tensor = torch.as_tensor(X_val_img, dtype=torch.float32).permute(0, 3, 1, 2)
    X_test_img_tensor = torch.as_tensor(X_test_img, dtype=torch.float32).permute(0, 3, 1, 2)
    y_train_tensor = prepare_target_tensor(y_train, task_type)
    y_val_tensor = prepare_target_tensor(y_val, task_type)
    y_test_tensor = prepare_target_tensor(y_test, task_type)

    # Normalize to [0, 1]
    #X_train_img_tensor = X_train_img_tensor / 255.0
    #X_val_img_tensor = X_val_img_tensor / 255.0
    #X_test_img_tensor = X_test_img_tensor / 255.0

    # Create DataLoaders
    train_dataset = TensorDataset(X_train_num_tensor, X_train_img_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_num_tensor, X_val_img_tensor, y_val_tensor)
    test_dataset = TensorDataset(X_test_num_tensor, X_test_img_tensor, y_test_tensor)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

    return train_loader, val_loader, test_loader, attributes, imgs_shape, le, class_weight

# %% [markdown]
# ## MODEL ARCHITECTURES

# %%
def find_divisors(n):
    divisors = []
    for i in range(1, int(n**0.5) + 1):
        if n % i == 0:
            divisors.append(i)
            if i != n // i:  # Check to include both divisors if they are not the same
                divisors.append(n // i)
    divisors.sort()
    return divisors

# %% [markdown]
# ### Vision Transformer

# %%
from models.vit_pytorch.simple_vit_with_register_tokens import ViT

# %%
class ViTMLP(nn.Module):
    def __init__(self, imgs_shape, num_input_dim, params, task, num_classes=None):
        super(ViTMLP, self).__init__()

        # Vision Transformer branch
        self.vit = ViT(
            image_size=imgs_shape,
            patch_size=params["patch_size"],
            dim=params["dim"],
            depth=params["depth"],
            heads=params["heads"],
            mlp_dim=params["mlp_dim"]
        )

        # Tabular MLP branch
        mlp_layers = []
        input_dim = num_input_dim
        for hidden_dim in params["mlp_hidden_dims"]:
            mlp_layers.append(nn.Linear(input_dim, hidden_dim))
            mlp_layers.append(nn.ReLU())
            input_dim = hidden_dim
        self.tabular_mlp = nn.Sequential(*mlp_layers)

        # Fusion MLP (Final classifier head)
        fusion_input_dim = params["dim"] + input_dim
        fusion_layers = []
        for hidden_dim in params["fusion_hidden_dims"]:
            fusion_layers.append(nn.Linear(fusion_input_dim, hidden_dim))
            fusion_layers.append(nn.ReLU())
            fusion_input_dim = hidden_dim

        output_dim = 1 if task in ['regression', 'binary'] else num_classes
        fusion_layers.append(nn.Linear(fusion_input_dim, output_dim))
        self.fusion_mlp = nn.Sequential(*fusion_layers)

        # Change identity to something else if needed
        self.activation = nn.Identity()

    def forward(self, num_input, vit_input):
        vit_feat = self.vit(vit_input)
        tabular_feat = self.tabular_mlp(num_input)
        fusion = torch.cat([vit_feat, tabular_feat], dim=1)
        output = self.fusion_mlp(fusion)
        return self.activation(output)

# %% [markdown]
# ### CNN

# %%
class CNNMLP(nn.Module):
    def __init__(self, imgs_shap, num_input_dim, params, task, num_classes=None):
        super(CNNMLP, self).__init__()
        
        # CNN branch
        if params["model"] == "model1":
            self.cnn_branch = nn.Sequential(
                nn.Conv2d(imgs_shape[0], 16, kernel_size=2),
                nn.ReLU(),
                nn.Flatten()
            )
        else:  # "model2"
            self.cnn_branch = nn.Sequential(
                nn.Conv2d(imgs_shape[0], out_channels=16, kernel_size=3),
                nn.ReLU(),
                nn.MaxPool2d(2, 2),
                nn.Conv2d(16, 32, kernel_size=3, padding=1),
                nn.ReLU(),
                nn.Conv2d(32, 64, kernel_size=3, padding=1),
                nn.ReLU(),
                nn.Flatten()
            )

        # Calculate the size of the flattened output
        self.flat_size = self._get_flat_size(imgs_shape)
        
        # Tabular MLP branch
        mlp_layers = []
        input_dim = num_input_dim
        for hidden_dim in params["mlp_hidden_dims"]:
            mlp_layers.append(nn.Linear(input_dim, hidden_dim))
            mlp_layers.append(nn.ReLU())
            input_dim = hidden_dim
        self.tabular_mlp = nn.Sequential(*mlp_layers)

        # Fusion MLP (Final classifier head)
        fusion_input_dim = self.flat_size + input_dim
        fusion_layers = []
        for hidden_dim in params["fusion_hidden_dims"]:
            fusion_layers.append(nn.Linear(fusion_input_dim, hidden_dim))
            fusion_layers.append(nn.ReLU())
            fusion_input_dim = hidden_dim

        # Determine output layer
        output_dim = 1 if task in ['regression', 'binary'] else num_classes
        fusion_layers.append(nn.Linear(fusion_input_dim, output_dim))
        self.fusion_mlp = nn.Sequential(*fusion_layers)

        # Change identity to something else if needed
        self.activation = nn.Identity()
        
    def _get_flat_size(self, imgs_shape):
        # Forward pass with dummy input to calculate flat size
        dummy_input = torch.zeros(4, *imgs_shape)
        x = self.cnn_branch(dummy_input)
        return x.size(1)

    def forward(self, num_input, cnn_input):
        cnn_feat = self.cnn_branch(cnn_input)
        tabular_feat = self.tabular_mlp(num_input)
        fusion = torch.cat([cnn_feat, tabular_feat], dim=1)
        output = self.fusion_mlp(fusion)
        return self.activation(output)

# %% [markdown]
# ### Resnet50

# %%
import torchvision.models as models

# %%
class ResNetMLP(nn.Module):
    def __init__(self, imgs_shape, num_input_dim, params, task_type, num_classes=None):
        super(ResNetMLP, self).__init__()

        # Load a ResNet50 with or without pretrained weights
        base_resnet = models.resnet50(weights=None)

        self.resnet_backbone = nn.Sequential(*list(base_resnet.children())[:-1])  # (B, 2048, 1, 1)
        self.flatten = nn.Flatten()  # Converts (B, 2048, 1, 1) → (B, 2048)

        # Tabular MLP branch
        tabular_layers = []
        input_dim = num_input_dim
        for hidden_dim in params["mlp_hidden_dims"]:
            tabular_layers.append(nn.Linear(input_dim, hidden_dim))
            tabular_layers.append(nn.ReLU())
            input_dim = hidden_dim
        self.tabular_mlp = nn.Sequential(*tabular_layers)

        # Create a dummy image based on the input image shape to calculate the output size
        dummy_img = torch.randn(4, *imgs_shape)  # (B, 3, H, W)
        with torch.no_grad():
            # Pass the dummy image through ResNet to get feature map
            img_feat = self.resnet_backbone(dummy_img)  
            resnet_output_dim = self.flatten(img_feat)

        # Fusion MLP head (ResNet features + Tabular MLP)
        fusion_input_dim = resnet_output_dim.shape[1] + input_dim
        fusion_layers = []
        for hidden_dim in params.get("fusion_hidden_dims", [128]):
            fusion_layers.append(nn.Linear(fusion_input_dim, hidden_dim))
            fusion_layers.append(nn.ReLU())
            fusion_input_dim = hidden_dim

        output_dim = 1 if task_type in ["regression", "binary"] else num_classes
        fusion_layers.append(nn.Linear(fusion_input_dim, output_dim))
        self.fusion_mlp = nn.Sequential(*fusion_layers)

        # Output activation
        self.activation = nn.Identity()

    def forward(self, num_input, img_input):
        # ResNet feature extraction
        img_feat = self.resnet_backbone(img_input)  # (B, 2048, 1, 1)
        img_feat = self.flatten(img_feat)           # (B, 2048)

        # Tabular feature extraction
        tab_feat = self.tabular_mlp(num_input)      # (B, D_tabular)

        # Fusion and classification
        fusion = torch.cat([img_feat, tab_feat], dim=1)

        output = self.fusion_mlp(fusion)

        return self.activation(output)

# %% [markdown]
# ## COMPILE AND FIT

# %%
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import joblib
import os
import gc
import copy

from models.utils import get_loss_fn, calculate_metrics, calculate_metrics_hybrid, calculate_metrics_hybrid_manuel, calculate_metrics_from_numpy, get_class_weighted_loss_fn

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from torch.optim.lr_scheduler import OneCycleLR
import matplotlib.pyplot as plt
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import os

def compile_and_fit(model, train_loader, val_loader, test_loader, dataset_name, 
                    model_name, image_name, trial_name=None, task='regression', epochs=200, max_lr=1, 
                    div_factor=10, final_div_factor=1, device='cuda', weight_decay=1e-2, save_model=False, class_weights=None, save_dir=None, study=None, patch=None, verbose=False):
    model = model.to(device)
    
    if class_weights != None:
        loss_fn = get_class_weighted_loss_fn(task, class_weights)
    else:
        loss_fn = get_loss_fn(task)

    # Compute min_lr from max_lr and div_factor
    min_lr = max_lr / div_factor

    optimizer = optim.AdamW(model.parameters(), lr=min_lr, weight_decay=weight_decay)
    
    total_steps = epochs * len(train_loader)
    scheduler = OneCycleLR(optimizer, max_lr=max_lr, div_factor=div_factor, final_div_factor=final_div_factor, total_steps=total_steps, pct_start=0.3, anneal_strategy="cos")
    
    best_val_loss = float('inf')
    best_model = None
    best_epoch = 0
    #early_stopping_counter = 0
    #patience = 10  # Early stopping patience

    history = {'train_loss': [], 'val_loss': [], 'learning_rate': [], 'epoch_time': []}

    if task == 'regression':
        history.update({'train_mse': [],  'val_mse': [], 'train_mae': [],  'val_mae': [], 'train_rmse': [], 'val_rmse': [], 'train_r2': [], 'val_r2': []})
    elif task in ['binary', 'multiclass']:
        history.update({'train_accuracy': [], 'val_accuracy': [], 'train_precision': [], 'val_precision': [], 'train_recall': [], 'val_recall': [], 'train_f1': [], 'val_f1': []})

    start_time = time.time()
    
    for epoch in range(epochs):
        epoch_start_time = time.time()

        model.train()
        train_loss = 0.0
        train_preds = []
        train_targets = []

        for num_data, img_data, targets in train_loader:
            num_data, img_data, targets = num_data.to(device, non_blocking=True), img_data.to(device, non_blocking=True), targets.to(device, non_blocking=True)
            
            optimizer.zero_grad()
            outputs = model(num_data, img_data)
            loss = loss_fn(outputs, targets)
            loss.backward()
            optimizer.step()
            scheduler.step()
            
            train_loss += loss.item()
            train_preds.extend(outputs.cpu().detach().numpy())
            train_targets.extend(targets.cpu().numpy())


        train_loss /= len(train_loader)
        if task == 'multiclass':
            y_train_pred = np.vstack(train_preds)
            y_train_true = train_targets
        else:
            y_train_pred = np.concatenate(train_preds)
            y_train_true = np.concatenate(train_targets)
        train_metrics = calculate_metrics_from_numpy(y_train_true, y_train_pred, task)

        model.eval()
        val_loss = 0.0
        val_preds = []
        val_targets = []
        with torch.no_grad():
            for num_data, img_data, targets in val_loader:
                num_data, img_data, targets = num_data.to(device, non_blocking=True), img_data.to(device, non_blocking=True), targets.to(device, non_blocking=True)
                outputs = model(num_data, img_data)
                loss = loss_fn(outputs, targets)
                
                val_loss += loss.item()
                val_preds.extend(outputs.cpu().numpy())
                val_targets.extend(targets.cpu().numpy())

        val_loss /= len(val_loader)
        if task == 'multiclass':
            y_val_pred = np.vstack(val_preds)
            y_val_true = val_targets
        else:
            y_val_pred = np.concatenate(val_preds)
            y_val_true = np.concatenate(val_targets)
        val_metrics = calculate_metrics_from_numpy(y_val_true, y_val_pred, task)
        
        # Get the current learning rate
        current_lr = scheduler.get_last_lr()

        epoch_time = time.time() - epoch_start_time

        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['learning_rate'].append(current_lr)
        history['epoch_time'].append(epoch_time)

        for k, v in train_metrics.items():
            history[f'train_{k}'].append(v)
        for k, v in val_metrics.items():
            history[f'val_{k}'].append(v)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = copy.deepcopy(model.state_dict())
            best_epoch = epoch + 1
            #early_stopping_counter = 0
        #else:
        #    early_stopping_counter += 1
        #    if early_stopping_counter >= patience:
        #        print(f"Early stopping at epoch {epoch + 1}")
        #        break

    total_time = time.time() - start_time
    model.load_state_dict(best_model)

    # Recompute metrics using the best model
    train_metrics, y_true_train, y_pred_train, y_prob_train = calculate_metrics_hybrid(model, train_loader, device, class_weights, task)
    val_metrics, y_true_val, y_pred_val, y_prob_val  = calculate_metrics_hybrid(model, val_loader, device, class_weights, task)
    test_metrics, y_true_test, y_pred_test, y_prob_test = calculate_metrics_hybrid(model, test_loader, device, class_weights, task)

    # Store recomputed metrics
    metrics = {
        'train_loss': train_metrics['loss'],
        'val_loss': val_metrics['loss'],
        'test_loss': test_metrics['loss'],
        'min_lr': min_lr,
        'max_lr': max_lr,
        'total_time': total_time,
        'average_epoch_time': sum(history['epoch_time']) / len(history['epoch_time'])
    }

    # Add task-specific metrics
    for k in train_metrics:
        if k != 'loss':
            metrics[f'train_{k}'] = train_metrics[k]
    for k in val_metrics:
        if k != 'loss':
            metrics[f'val_{k}'] = val_metrics[k]
    for k in test_metrics:
        if k != 'loss':
            metrics[f'test_{k}'] = test_metrics[k]
            
    if verbose:     
        print(f"\nTraining completed in {total_time:.2f} seconds")
        print(f"Best model found at epoch {best_epoch}/{epochs}")
        print(f"Best Train Loss: {metrics['train_loss']:.4f}, Best Val Loss: {metrics['val_loss']:.4f}")
        print(metrics)
    
    if save_model:
        if model_name == "CNN_hybrid":
            save_path = os.path.join(save_dir, f"{model_name}/{image_name}/best_model/{trial_name}")
        else:
            save_path = os.path.join(save_dir, f"{model_name}/{image_name}/best_model/{trial_name}{patch}")
        os.makedirs(save_path, exist_ok=True)

        plot_metric(history['train_loss'], history['val_loss'], 'Loss', save_path)
        if task == 'regression':
            plot_metric(history['train_mse'], history['val_mse'], 'MSE', save_path)
            plot_metric(history['train_rmse'], history['val_rmse'], 'RMSE', save_path)
        else:
            plot_metric(history['train_accuracy'], history['val_accuracy'], 'Accuracy', save_path)
            plot_metric(history['train_f1'], history['val_f1'], 'F1', save_path)

        plot_learning_rate(history['learning_rate'], save_path)

        # Save metrics
        os.makedirs(save_path, exist_ok=True)
        with open(f'{save_path}/best_model_metrics.txt', 'w') as f:
            for key, value in metrics.items():
                f.write(f'{key}: {value}\n')

        # Save model
        torch.save(best_model, f"{save_path}/best_model.pth")
        print(f"Best model saved to {save_path}/best_model.pth")

        # Additional plots for classification
        if task in ["binary"]:
            plot_extra("Train", y_true_train, y_pred_train, y_prob_train, save_path)
            plot_extra("Validation", y_true_val, y_pred_val, y_prob_val, save_path)
            plot_extra("Test", y_true_test, y_pred_test, y_prob_test, save_path)

    del model
    torch.cuda.empty_cache()
    gc.collect()

    return metrics


def plot_extra(split_name, y_true, y_pred, y_prob, save_path):
    y_true = y_true.ravel()
    y_pred = y_pred.ravel()

    # ROC Curve
    RocCurveDisplay.from_predictions(y_true, y_prob)
    auc_score = roc_auc_score(y_true, y_prob)
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
    plt.title(f"{split_name} ROC Curve (AUC = {auc_score:.2f})")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.grid(True)
    plt.savefig(os.path.join(save_path, f"{split_name.lower()}_roc_curve.png"))
    plt.close("all")

    # Precision-Recall Curve
    PrecisionRecallDisplay.from_predictions(y_true, y_prob)
    avg_prec = average_precision_score(y_true, y_prob)
    plt.title(f"{split_name} PR Curve (AP = {avg_prec:.2f})")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.grid(True)
    plt.savefig(os.path.join(save_path, f"{split_name.lower()}_pr_curve.png"))
    plt.close("all")

    # Normalized confusion matrix
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred, normalize='true').plot(cmap='Blues')
    plt.title(f"{split_name} Confusion Matrix (Normalized)")
    plt.grid(False)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.savefig(os.path.join(save_path, f"{split_name.lower()}_confusion_matrix_normalized.png"))
    plt.close("all")

    # Raw confusion matrix
    ConfusionMatrixDisplay.from_predictions(y_true, y_pred, normalize=None).plot(cmap='Blues')
    plt.title(f"{split_name} Confusion Matrix (Counts)")
    plt.grid(False)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.savefig(os.path.join(save_path, f"{split_name.lower()}_confusion_matrix_counts.png"))
    plt.close("all")


def plot_metric(train_metric, val_metric, metric_name, save_path):
    plt.figure()
    plt.plot(train_metric, label=f'Train {metric_name}')
    plt.plot(val_metric, label=f'Validation {metric_name}')
    plt.xlabel('Epoch')
    plt.ylabel(metric_name)
    plt.legend()
    plt.title(f'{metric_name} vs. Epoch')
    save_path = f"{save_path}/{metric_name.lower()}_plot.png"
    plt.savefig(save_path)
    plt.close("all")

def plot_learning_rate(learning_rates, save_path):
    plt.figure()
    plt.plot(learning_rates)
    plt.xlabel('Epoch')
    plt.ylabel('Learning Rate')
    plt.title('Learning Rate vs. Epoch')
    save_path = f"{save_path}/learning_rate_plot.png"
    plt.savefig(save_path)
    plt.close("all")

# %% [markdown]
# # EXPERIMENTS

# %% [markdown]
# ## HyViT

# %%
save_dir =  os.path.join("logs", task_type, dataset_name)
model_name = "ViT_hybrid"

# Load config
with open(f"./configs/preprocess/{dataset_name}.json") as f:
    config = json.load(f)
batch_size = config["batch_size"]

epochs = [100,200]
n_trials = 100

if task_type.lower() == 'multiclass':
    num_classes = df.iloc[:,-1].nunique()
else:
    num_classes = 1

device='cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
save_dir =  os.path.join("logs", task_type, dataset_name)
model_name = "CNN_hybrid"

# Load config
with open(f"./configs/preprocess/{dataset_name}.json") as f:
    config = json.load(f)
batch_size = config["batch_size"]

epochs = [100,200]
n_trials = 50

if task_type.lower() == 'multiclass':
    num_classes = df.iloc[:,-1].nunique()
else:
    num_classes = 1

device='cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
def objective(trial, model_name, image_name, task_type, 
              train_loader, val_loader, test_loader,
              divisors, attributes, imgs_shape, num_classes=None,
              device='cuda', save_dir=None, class_weight=None, epochs=100):
    
    if model_name == "ViT_hybrid":
        task = task_type.lower()

        params = load_search_space(model_name, trial)

        params["patch_size"] = trial.suggest_categorical("patch_size", divisors)

        params["mlp_hidden_dims"] = json.loads(params["mlp_hidden_dims"])

        params["fusion_hidden_dims"] = json.loads(params["fusion_hidden_dims"])

        if params["dim"] % params["heads"] != 0:
            raise optuna.exceptions.TrialPruned()

        with open(f"configs/optuna_search/{model_name}.json", "r") as f:
            full_config = json.load(f)

        config = full_config[model_name]["fit"]  # Access the model key

        # Initialize model
        model = ViTMLP(imgs_shape[1], attributes, params, task, num_classes)
    else:
        task = task_type.lower()

        params = load_search_space(model_name, trial)
        
        params["mlp_hidden_dims"] = json.loads(params["mlp_hidden_dims"])
        
        params["fusion_hidden_dims"] = json.loads(params["fusion_hidden_dims"])
        
        with open(f"configs/optuna_search/{model_name}.json", "r") as f:
            full_config = json.load(f)
            
        config = full_config[model_name]["fit"]  # Access the model key
        
        # Build and train model
        model = CNNMLP(imgs_shape, attributes, params, task, num_classes)
        
    metrics = compile_and_fit(
        model,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        model_name=f"trial_{trial.number}",
        image_name=image_name,
        task=task,  # assumed to be defined externally
        max_lr=trial.suggest_float("max_lr", config["max_lr"][1], config["max_lr"][2], log=True),
        div_factor=trial.suggest_int("div_factor", config["div_factor"][1], config["div_factor"][2]),
        final_div_factor=trial.suggest_int("final_div_factor", config["final_div_factor"][1], config["final_div_factor"][2]),
        weight_decay=trial.suggest_float("weight_decay", config["weight_decay"][1], config["weight_decay"][2], log=True),
        epochs=trial.suggest_categorical("epochs", [100, 200]),
        save_model=False,
        class_weights=class_weight
    )

    save_dir = os.path.join(save_dir, model_name, image_name, "optuna")
    os.makedirs(save_dir, exist_ok=True)

    if task == 'regression':
        score = metrics["val_rmse"]
        with open(f"{save_dir}/optuna_trials_log.txt", "a") as f:
            f.write(f"Trial {trial.number} - VAL-RMSE: {score:.4f}, Params: {params}\n")
            f.write("=" * 60 + "\n")
    
    elif task == 'binary':
        score = metrics["val_roc_auc"]
        with open(f"{save_dir}/optuna_trials_log.txt", "a") as f:
            f.write(f"Trial {trial.number} - VAL-AUC: {score:.4f}, Params: {params}\n")
            f.write("=" * 60 + "\n")

    elif task == 'multiclass':
        score = metrics["val_accuracy"]
        with open(f"{save_dir}/optuna_trials_log.txt", "a") as f:
            f.write(f"Trial {trial.number} - VAL-Accuracy: {score:.4f}, Params: {params}\n")
            f.write("=" * 60 + "\n")
    else:
        raise ValueError(f"Unsupported task type: {task_type}")
    
    return score

# %%
def evaluate_best_model(best_trial, train_loader, val_loader, test_loader, 
                        dataset_name, image_name, task_type, save_dir, attributes, imgs_shape, trial_name, 
                        class_weight=None, num_classes=None, epochs=10):

    task = task_type.lower()
    best_params = best_trial.params

    print(f"\nBest Trial: {best_trial.number}")
    print(f"  Best Score: {best_trial.value:.4f}")
    print("  Best Hyperparameters:")
    for k, v in best_params.items():
        print(f"    {k}: {v}")
    
    if model_name == "ViT_hybrid":
        # Extract architecture-related parameters
        architecture_params = {
            k: v for k, v in best_params.items()
            if k in ["patch_size", "dim", "depth", "heads", "mlp_dim", "mlp_hidden_dims", "fusion_hidden_dims"]
        }

        # Convert JSON string to list if necessary
        if isinstance(architecture_params.get("mlp_hidden_dims"), str):
            architecture_params["mlp_hidden_dims"] = json.loads(architecture_params["mlp_hidden_dims"])

        if isinstance(architecture_params.get("fusion_hidden_dims"), str):
            architecture_params["fusion_hidden_dims"] = json.loads(architecture_params["fusion_hidden_dims"])
        
        patch = f"_patch{architecture_params['patch_size']}"
        # Initialize model
        model = ViTMLP(imgs_shape[1], attributes, architecture_params, task, num_classes)
    else:
        # Extract architecture-related parameters
        architecture_params = {
            k: v for k, v in best_params.items()
            if k in ["mlp_hidden_dims", "fusion_hidden_dims", "model"]
        }
        # Convert JSON string to list if necessary
        if isinstance(architecture_params.get("mlp_hidden_dims"), str):
            architecture_params["mlp_hidden_dims"] = json.loads(architecture_params["mlp_hidden_dims"])
            
        if isinstance(architecture_params.get("fusion_hidden_dims"), str):
            architecture_params["fusion_hidden_dims"] = json.loads(architecture_params["fusion_hidden_dims"])
        
        patch = ""
        
        model = CNNMLP(imgs_shape, attributes, architecture_params, task, num_classes)

    # Train and evaluate
    metrics = compile_and_fit(
        model,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=image_name,
        model_name=model_name,
        trial_name=f"trial_{best_trial.number}",
        task=task,
        max_lr=best_params["max_lr"],
        div_factor=best_params["div_factor"],
        final_div_factor=best_params["final_div_factor"],
        weight_decay=best_params["weight_decay"],
        epochs=best_params["epochs"],
        save_model=True,
        class_weights=class_weight,
        save_dir=save_dir,
        patch=patch
    )

    # Save best hyperparameters
    params_file = os.path.join(save_dir, f"{model_name}/{image_name}/best_model/trial_{best_trial.number}{patch}", "best_params.json")
    os.makedirs(os.path.dirname(params_file), exist_ok=True)

    with open(params_file, "w") as f:
        json.dump(best_params, f, indent=4)

    return metrics

# %%
import random
import numpy as np
import torch

def set_model_seed(seed: int):
    # Python built-in RNG
    random.seed(seed)
    # NumPy RNG
    np.random.seed(seed)
    # Torch RNG
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you use multi-GPU
    
    # For reproducibility
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### EXPERIMENT: TINTO

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"
name = f"TINTO_blur"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/TINTO_blur/train/regression.csv
# SyntheticImages/Regression/boston/TINTO_blur/val/regression.csv
# SyntheticImages/Regression/boston/TINTO_blur/test/regression.csv
# Images shape:  (3, 20, 20)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 2, 4, 5, 10, 20]

# %%
divisors = [5, 10, 20]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-14 10:27:46,440] A new study created in memory with name: no-name-8c3decf7-cb00-4a2e-91c6-b7bde9a5c0b1
# [I 2025-09-14 10:28:03,236] Trial 0 finished with value: 3.730832258958103 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0002293340002060818, 'div_factor': 34, 'final_div_factor': 839, 'weight_decay': 5.66369279943869e-06, 'epochs': 200}. Best is trial 0 with value: 3.730832258958103.
# [I 2025-09-14 10:28:11,093] Trial 1 finished with value: 3.577315726236053 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.019579167092847825, 'div_factor': 80, 'final_div_factor': 369, 'weight_decay': 0.00010276907301605183, 'epochs': 100}. Best is trial 1 with value: 3.577315726236053.
# [I 2025-09-14 10:28:27,551] Trial 2 finished with value: 3.528627079800066 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.01974807161848634, 'div_factor': 73, 'final_div_factor': 800, 'weight_decay': 3.864813756881836e-06, 'epochs': 200}. Best is trial 2 with value: 3.528627079800066.
# [I 2025-09-14 10:28:34,903] Trial 3 finished with value: 4.372455401882914 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00011246777008803096, 'div_factor': 35, 'final_div_factor': 304, 'weight_decay': 0.00015799565828909356, 'epochs': 100}. Best is trial 2 with value: 3.528627079800066.
# [I 2025-09-14 10:28:49,608] Trial 4 finished with value: 3.723232484873 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.010667074780124831, 'div_factor': 49, 'final_div_factor': 867, 'weight_decay': 0.009953540675886255, 'epochs': 200}. Best is trial 2 with value: 3.528627079800066.
# [I 2025-09-14 10:29:05,039] Trial 5 finished with value: 3.8323588722158655 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00011174040286529657, 'div_factor': 38, 'final_div_factor': 208, 'weight_decay': 0.0060899918155480435, 'epochs': 200}. Best is trial 2 with value: 3.528627079800066.
# [I 2025-09-14 10:29:12,599] Trial 6 finished with value: 3.859634328924845 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.03076097472390933, 'div_factor': 51, 'final_div_factor': 117, 'weight_decay': 0.0012340108800218898, 'epochs': 100}. Best is trial 2 with value: 3.528627079800066.
# [I 2025-09-14 10:29:29,732] Trial 7 finished with value: 3.5449002183825393 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0006119877968463556, 'div_factor': 69, 'final_div_factor': 154, 'weight_decay': 1.112865327082503e-05, 'epochs': 200}. Best is trial 2 with value: 3.528627079800066.
# [I 2025-09-14 10:29:37,034] Trial 8 finished with value: 4.205350492296869 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00017391567080473838, 'div_factor': 40, 'final_div_factor': 790, 'weight_decay': 0.00018158215065943839, 'epochs': 100}. Best is trial 2 with value: 3.528627079800066.
# [I 2025-09-14 10:29:53,216] Trial 9 finished with value: 3.6600816000508463 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.028371041999616577, 'div_factor': 35, 'final_div_factor': 283, 'weight_decay': 0.00011470501180308146, 'epochs': 200}. Best is trial 2 with value: 3.528627079800066.
# [I 2025-09-14 10:30:10,310] Trial 10 finished with value: 3.4134772386117516 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0030894002134766447, 'div_factor': 100, 'final_div_factor': 636, 'weight_decay': 1.268931320103456e-06, 'epochs': 200}. Best is trial 10 with value: 3.4134772386117516.
# [I 2025-09-14 10:30:27,379] Trial 11 finished with value: 3.525935942935101 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0030236543242711184, 'div_factor': 100, 'final_div_factor': 651, 'weight_decay': 1.3313166904225005e-06, 'epochs': 200}. Best is trial 10 with value: 3.4134772386117516.
# [I 2025-09-14 10:30:44,485] Trial 12 finished with value: 3.4084245932252393 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0024184003406041775, 'div_factor': 100, 'final_div_factor': 565, 'weight_decay': 2.2783742103126664e-06, 'epochs': 200}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:31:01,582] Trial 13 finished with value: 3.497375185241116 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0024485238620132097, 'div_factor': 98, 'final_div_factor': 507, 'weight_decay': 1.1518143346504064e-06, 'epochs': 200}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:31:18,729] Trial 14 finished with value: 3.6221304749907124 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0008840628148545913, 'div_factor': 17, 'final_div_factor': 592, 'weight_decay': 2.0218641547325123e-05, 'epochs': 200}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:31:35,826] Trial 15 finished with value: 3.74348494112031 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.006342340788190678, 'div_factor': 86, 'final_div_factor': 445, 'weight_decay': 3.338269068968699e-06, 'epochs': 200}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:31:52,913] Trial 16 finished with value: 3.6497511530663407 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0973524528390217, 'div_factor': 90, 'final_div_factor': 679, 'weight_decay': 2.411635775865354e-05, 'epochs': 200}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:32:09,948] Trial 17 finished with value: 3.435271355628868 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0012845622600466701, 'div_factor': 64, 'final_div_factor': 997, 'weight_decay': 1.038544771798891e-06, 'epochs': 200}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:32:18,604] Trial 18 finished with value: 3.491712158076728 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005648350608061656, 'div_factor': 90, 'final_div_factor': 518, 'weight_decay': 0.0006254911740805084, 'epochs': 100}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:32:35,092] Trial 19 finished with value: 3.6923143672577114 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0004597442115152424, 'div_factor': 79, 'final_div_factor': 727, 'weight_decay': 3.9290895036914136e-05, 'epochs': 200}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:32:52,164] Trial 20 finished with value: 3.552119473956807 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.001527242957331378, 'div_factor': 100, 'final_div_factor': 433, 'weight_decay': 2.507208209948102e-06, 'epochs': 200}. Best is trial 12 with value: 3.4084245932252393.
# [I 2025-09-14 10:33:09,278] Trial 21 finished with value: 3.404751789384133 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0015702376552288984, 'div_factor': 65, 'final_div_factor': 1000, 'weight_decay': 1.0560451616913965e-06, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:33:26,300] Trial 22 finished with value: 3.492522972430054 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005705667872581721, 'div_factor': 56, 'final_div_factor': 947, 'weight_decay': 9.2350778495767e-06, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:33:43,393] Trial 23 finished with value: 3.517879322803665 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0019892922241159993, 'div_factor': 14, 'final_div_factor': 611, 'weight_decay': 2.276520393543249e-06, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:34:00,383] Trial 24 finished with value: 3.506777604334179 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0039881699043319025, 'div_factor': 92, 'final_div_factor': 715, 'weight_decay': 8.030193293108637e-06, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:34:17,491] Trial 25 finished with value: 3.5889417243535267 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0004070229952605909, 'div_factor': 80, 'final_div_factor': 885, 'weight_decay': 1.717334472403834e-06, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:34:26,139] Trial 26 finished with value: 3.6512454742852842 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0009047155434417824, 'div_factor': 22, 'final_div_factor': 444, 'weight_decay': 4.7690229229907895e-05, 'epochs': 100}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:34:43,180] Trial 27 finished with value: 3.404925587607035 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.010045240140578879, 'div_factor': 68, 'final_div_factor': 557, 'weight_decay': 3.981172886254662e-06, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:35:00,229] Trial 28 finished with value: 3.4569951114813082 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.009721095053261136, 'div_factor': 60, 'final_div_factor': 534, 'weight_decay': 5.056888323756245e-06, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:35:16,746] Trial 29 finished with value: 3.704330570011784 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.010615180502732264, 'div_factor': 45, 'final_div_factor': 331, 'weight_decay': 1.4366132806914374e-05, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:35:33,286] Trial 30 finished with value: 3.687261929343167 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0012124601081894488, 'div_factor': 70, 'final_div_factor': 761, 'weight_decay': 3.592846974801887e-06, 'epochs': 200}. Best is trial 21 with value: 3.404751789384133.
# [I 2025-09-14 10:35:50,368] Trial 31 finished with value: 3.3977482239218464 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.003723598133459432, 'div_factor': 64, 'final_div_factor': 588, 'weight_decay': 1.0040531249503331e-06, 'epochs': 200}. Best is trial 31 with value: 3.3977482239218464.
# [I 2025-09-14 10:36:07,350] Trial 32 finished with value: 3.559918857249788 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.004764704909666115, 'div_factor': 65, 'final_div_factor': 575, 'weight_decay': 6.89576048185984e-06, 'epochs': 200}. Best is trial 31 with value: 3.3977482239218464.
# [I 2025-09-14 10:36:24,389] Trial 33 finished with value: 3.542888939073159 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0020691566209126875, 'div_factor': 75, 'final_div_factor': 388, 'weight_decay': 2.2465847787901596e-06, 'epochs': 200}. Best is trial 31 with value: 3.3977482239218464.
# [I 2025-09-14 10:36:31,951] Trial 34 finished with value: 3.6268262537971037 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.01518536719241575, 'div_factor': 59, 'final_div_factor': 494, 'weight_decay': 4.527209107274047e-06, 'epochs': 100}. Best is trial 31 with value: 3.3977482239218464.
# [I 2025-09-14 10:36:48,452] Trial 35 finished with value: 3.3561176920408484 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.008069256568493487, 'div_factor': 75, 'final_div_factor': 828, 'weight_decay': 2.2554303835191425e-06, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:37:03,752] Trial 36 finished with value: 3.736632873581989 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.05568181672900794, 'div_factor': 75, 'final_div_factor': 908, 'weight_decay': 4.753555791620582e-06, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:37:20,250] Trial 37 finished with value: 3.8111549881564777 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.008945537758612607, 'div_factor': 65, 'final_div_factor': 848, 'weight_decay': 1.0298115243775763e-06, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:37:27,533] Trial 38 finished with value: 4.0008246048684635 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.015869744156585524, 'div_factor': 53, 'final_div_factor': 994, 'weight_decay': 1.8611063188887609e-06, 'epochs': 100}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:37:44,216] Trial 39 finished with value: 3.6924555180374954 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0214086849004886, 'div_factor': 79, 'final_div_factor': 796, 'weight_decay': 0.0028456651452486606, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:37:58,671] Trial 40 finished with value: 3.6598790083100767 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.007188150711817523, 'div_factor': 71, 'final_div_factor': 932, 'weight_decay': 0.0002395577769110085, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:38:15,174] Trial 41 finished with value: 3.458814671735195 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.004307346591311948, 'div_factor': 60, 'final_div_factor': 674, 'weight_decay': 2.9397973647534955e-06, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:38:31,709] Trial 42 finished with value: 3.613958577774194 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0033419779519366123, 'div_factor': 47, 'final_div_factor': 573, 'weight_decay': 1.994488899845616e-06, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:38:48,559] Trial 43 finished with value: 3.539906651618493 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0016707370792205768, 'div_factor': 85, 'final_div_factor': 827, 'weight_decay': 1.4778321073107704e-06, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:39:05,160] Trial 44 finished with value: 3.372966012167671 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.002801629266441811, 'div_factor': 29, 'final_div_factor': 750, 'weight_decay': 6.143321583511541e-06, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:39:22,291] Trial 45 finished with value: 3.4756024010041373 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.013835359797458603, 'div_factor': 29, 'final_div_factor': 753, 'weight_decay': 1.241882938430549e-05, 'epochs': 200}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:39:30,908] Trial 46 finished with value: 3.4959544915962524 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.007852707912937839, 'div_factor': 42, 'final_div_factor': 816, 'weight_decay': 5.21881255470577e-06, 'epochs': 100}. Best is trial 35 with value: 3.3561176920408484.
# [I 2025-09-14 10:39:47,353] Trial 47 finished with value: 3.3383611589612547 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0029687835319354306, 'div_factor': 67, 'final_div_factor': 631, 'weight_decay': 6.9146029953649685e-06, 'epochs': 200}. Best is trial 47 with value: 3.3383611589612547.
# [I 2025-09-14 10:40:03,823] Trial 48 finished with value: 3.4974373563837586 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0029660317486239988, 'div_factor': 26, 'final_div_factor': 698, 'weight_decay': 6.503982806926982e-05, 'epochs': 200}. Best is trial 47 with value: 3.3383611589612547.
# [I 2025-09-14 10:40:18,187] Trial 49 finished with value: 3.9704051733929826 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0007405208814293032, 'div_factor': 56, 'final_div_factor': 643, 'weight_decay': 1.9380017420104456e-05, 'epochs': 200}. Best is trial 47 with value: 3.3383611589612547.

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 47, ValObjective: 3.3384
#
# Best Trial: 47
#   Best Score: 3.3384
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0029687835319354306
#     div_factor: 67
#     final_div_factor: 631
#     weight_decay: 6.9146029953649685e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/TINTO_blur/best_model/trial_47/best_model.pth
#   Seed 0: test_loss=7.140422, val_loss=11.210828, train_loss=2.538118
#
# Best Trial: 47
#   Best Score: 3.3384
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0029687835319354306
#     div_factor: 67
#     final_div_factor: 631
#     weight_decay: 6.9146029953649685e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/TINTO_blur/best_model/trial_47/best_model.pth
#   Seed 1: test_loss=15.777128, val_loss=13.903922, train_loss=9.168005
#
# Best Trial: 47
#   Best Score: 3.3384
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0029687835319354306
#     div_factor: 67
#     final_div_factor: 631
#     weight_decay: 6.9146029953649685e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/TINTO_blur/best_model/trial_47/best_model.pth
#   Seed 2: test_loss=8.218426, val_loss=10.510198, train_loss=3.378452
#
# Best Trial: 47
#   Best Score: 3.3384
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0029687835319354306
#     div_factor: 67
#     final_div_factor: 631
#     weight_decay: 6.9146029953649685e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/TINTO_blur/best_model/trial_47/best_model.pth
#   Seed 3: test_loss=7.404230, val_loss=13.147553, train_loss=3.237780
#
# Best Trial: 47
#   Best Score: 3.3384
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0029687835319354306
#     div_factor: 67
#     final_div_factor: 631
#     weight_decay: 6.9146029953649685e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/TINTO_blur/best_model/trial_47/best_model.pth
#   Seed 4: test_loss=8.490076, val_loss=11.646253, train_loss=3.671068
#   → test_loss Mean ± Std: 9.406057 ± 3.604874
# Saved to: logs/Regression/boston/CNN_hybrid/TINTO_blur/best_model/trial_47/best_results_mean.txt

# %% [markdown]
# ### EXPERIMENT: IGTD

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"
name = f"IGTD"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/IGTD/train/regression.csv
# SyntheticImages/Regression/boston/IGTD/val/regression.csv
# SyntheticImages/Regression/boston/IGTD/test/regression.csv
# Images shape:  (3, 5, 5)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 5]

# %%
divisors = [1, 5]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-14 10:41:43,845] A new study created in memory with name: no-name-5411d37d-257e-4fdb-9067-fdb241cb450d
# [I 2025-09-14 10:41:58,150] Trial 0 finished with value: 4.358333777773502 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0003451368516727994, 'div_factor': 43, 'final_div_factor': 807, 'weight_decay': 3.3282004097919553e-06, 'epochs': 200}. Best is trial 0 with value: 4.358333777773502.
# [I 2025-09-14 10:42:05,090] Trial 1 finished with value: 4.512188616969852 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0010843518820103527, 'div_factor': 14, 'final_div_factor': 650, 'weight_decay': 0.005608433865874547, 'epochs': 100}. Best is trial 0 with value: 4.358333777773502.
# [I 2025-09-14 10:42:12,964] Trial 2 finished with value: 4.101834765888952 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0005787634798754538, 'div_factor': 34, 'final_div_factor': 716, 'weight_decay': 0.002519048285716302, 'epochs': 100}. Best is trial 2 with value: 4.101834765888952.
# [I 2025-09-14 10:42:28,935] Trial 3 finished with value: 3.681734524042952 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0006845996891244945, 'div_factor': 83, 'final_div_factor': 851, 'weight_decay': 0.00031745911898858935, 'epochs': 200}. Best is trial 3 with value: 3.681734524042952.
# [I 2025-09-14 10:42:35,491] Trial 4 finished with value: 4.423616639191537 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.029612329141650802, 'div_factor': 23, 'final_div_factor': 416, 'weight_decay': 4.616969526961813e-06, 'epochs': 100}. Best is trial 3 with value: 3.681734524042952.
# [I 2025-09-14 10:42:42,854] Trial 5 finished with value: 4.552984688193323 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.002158951679510717, 'div_factor': 25, 'final_div_factor': 731, 'weight_decay': 1.1632167265174044e-06, 'epochs': 100}. Best is trial 3 with value: 3.681734524042952.
# [I 2025-09-14 10:42:49,704] Trial 6 finished with value: 3.746398213318214 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.015573431496514821, 'div_factor': 81, 'final_div_factor': 500, 'weight_decay': 2.2954114572791325e-05, 'epochs': 100}. Best is trial 3 with value: 3.681734524042952.
# [I 2025-09-14 10:42:57,011] Trial 7 finished with value: 5.058152392365185 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0001436948944964613, 'div_factor': 44, 'final_div_factor': 105, 'weight_decay': 0.0035971687519767478, 'epochs': 100}. Best is trial 3 with value: 3.681734524042952.
# [I 2025-09-14 10:43:03,244] Trial 8 finished with value: 4.9848102630656514 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.05654380310155376, 'div_factor': 98, 'final_div_factor': 338, 'weight_decay': 1.0170004897536564e-05, 'epochs': 100}. Best is trial 3 with value: 3.681734524042952.
# [I 2025-09-14 10:43:17,137] Trial 9 finished with value: 3.6888515775649893 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0019764865290247693, 'div_factor': 39, 'final_div_factor': 981, 'weight_decay': 0.0002510869850846015, 'epochs': 200}. Best is trial 3 with value: 3.681734524042952.
# [I 2025-09-14 10:43:31,089] Trial 10 finished with value: 3.8912030751909477 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.008145643080243266, 'div_factor': 78, 'final_div_factor': 962, 'weight_decay': 0.0003772301426743963, 'epochs': 200}. Best is trial 3 with value: 3.681734524042952.
# [I 2025-09-14 10:43:45,519] Trial 11 finished with value: 3.578827368419267 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005290883133639241, 'div_factor': 63, 'final_div_factor': 993, 'weight_decay': 0.0001842593540169443, 'epochs': 200}. Best is trial 11 with value: 3.578827368419267.
# [I 2025-09-14 10:44:01,499] Trial 12 finished with value: 3.3379179103532977 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.011681942169144968, 'div_factor': 65, 'final_div_factor': 870, 'weight_decay': 6.397999571246721e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:44:17,865] Trial 13 finished with value: 3.4601169414272763 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00648945134645584, 'div_factor': 65, 'final_div_factor': 1000, 'weight_decay': 6.390752059383796e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:44:34,105] Trial 14 finished with value: 3.491134314062999 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.01162293056381306, 'div_factor': 61, 'final_div_factor': 831, 'weight_decay': 6.855698880955318e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:44:50,396] Trial 15 finished with value: 3.6442116027848304 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0041519506165333874, 'div_factor': 69, 'final_div_factor': 597, 'weight_decay': 4.305358212860588e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:45:06,734] Trial 16 finished with value: 4.1614232958996435 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0802972335060259, 'div_factor': 54, 'final_div_factor': 887, 'weight_decay': 0.0009385015271369762, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:45:23,145] Trial 17 finished with value: 3.7633529710102427 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.026711400933232113, 'div_factor': 96, 'final_div_factor': 233, 'weight_decay': 2.0020103308555258e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:45:36,771] Trial 18 finished with value: 3.7782998674815156 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.021867046650956654, 'div_factor': 51, 'final_div_factor': 735, 'weight_decay': 8.039858461523574e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:45:53,168] Trial 19 finished with value: 3.4653236031077057 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.007054250375888787, 'div_factor': 73, 'final_div_factor': 927, 'weight_decay': 0.0008845289096699919, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:46:09,521] Trial 20 finished with value: 3.825008197850437 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.002903828623822315, 'div_factor': 90, 'final_div_factor': 520, 'weight_decay': 1.2246576316586008e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:46:25,881] Trial 21 finished with value: 3.58396375270804 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.007335684521955559, 'div_factor': 71, 'final_div_factor': 909, 'weight_decay': 0.0010020922997561, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:46:42,073] Trial 22 finished with value: 3.5554928045563465 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.011034371882948998, 'div_factor': 72, 'final_div_factor': 921, 'weight_decay': 0.0008699966955837285, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:46:58,327] Trial 23 finished with value: 3.554753631982706 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0434890570686882, 'div_factor': 62, 'final_div_factor': 794, 'weight_decay': 0.00016689048793486856, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:47:14,520] Trial 24 finished with value: 3.51303249137571 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005089039916481091, 'div_factor': 87, 'final_div_factor': 1000, 'weight_decay': 0.00993595412866186, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:47:30,334] Trial 25 finished with value: 3.6073293462348337 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.001484912568939622, 'div_factor': 75, 'final_div_factor': 901, 'weight_decay': 3.599628593213638e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:47:44,724] Trial 26 finished with value: 3.701753901713692 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.017448296159627015, 'div_factor': 64, 'final_div_factor': 647, 'weight_decay': 0.000122711192845861, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:48:01,020] Trial 27 finished with value: 3.457528736935651 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0035242947705060885, 'div_factor': 54, 'final_div_factor': 770, 'weight_decay': 0.0005266961325394694, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:48:17,202] Trial 28 finished with value: 3.6382776641664205 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.003786552972743558, 'div_factor': 49, 'final_div_factor': 778, 'weight_decay': 0.0004189135669490752, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:48:30,579] Trial 29 finished with value: 4.510522619446344 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.000210296521205146, 'div_factor': 55, 'final_div_factor': 833, 'weight_decay': 5.2362748033991734e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:48:46,875] Trial 30 finished with value: 3.6696592747569983 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.000995101980610126, 'div_factor': 44, 'final_div_factor': 694, 'weight_decay': 3.7869292484997853e-06, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:49:02,977] Trial 31 finished with value: 3.543040214919748 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0069251035673670355, 'div_factor': 68, 'final_div_factor': 929, 'weight_decay': 0.0006267136556374974, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:49:24,136] Trial 32 finished with value: 3.6300442556830865 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0029076846601331133, 'div_factor': 59, 'final_div_factor': 875, 'weight_decay': 0.0018661885452058958, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:49:40,407] Trial 33 finished with value: 3.4298655956838258 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.011493727526894093, 'div_factor': 57, 'final_div_factor': 781, 'weight_decay': 0.0016879914757503378, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:49:56,762] Trial 34 finished with value: 3.469146430929158 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.011378321655134435, 'div_factor': 48, 'final_div_factor': 769, 'weight_decay': 0.0019398253794782945, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:50:11,297] Trial 35 finished with value: 4.316115038960502 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.034071568695457015, 'div_factor': 56, 'final_div_factor': 641, 'weight_decay': 0.004237893143408139, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:50:19,661] Trial 36 finished with value: 4.19800831936852 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.016439031836323136, 'div_factor': 37, 'final_div_factor': 815, 'weight_decay': 0.00013295539304178437, 'epochs': 100}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:50:34,952] Trial 37 finished with value: 3.9692503846479417 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0005246249119559006, 'div_factor': 29, 'final_div_factor': 692, 'weight_decay': 2.6107055401722827e-05, 'epochs': 200}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:50:42,968] Trial 38 finished with value: 3.6292247488729643 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0020972122035122684, 'div_factor': 66, 'final_div_factor': 580, 'weight_decay': 0.0015315037211653627, 'epochs': 100}. Best is trial 12 with value: 3.3379179103532977.
# [I 2025-09-14 10:50:57,934] Trial 39 finished with value: 3.259495435411628 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.010206934596553034, 'div_factor': 59, 'final_div_factor': 744, 'weight_decay': 7.501393203667051e-06, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:51:05,453] Trial 40 finished with value: 4.680017628432761 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.010363463439457155, 'div_factor': 12, 'final_div_factor': 733, 'weight_decay': 2.1682915278782884e-06, 'epochs': 100}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:51:20,553] Trial 41 finished with value: 3.7655368652160055 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0056114450672939, 'div_factor': 58, 'final_div_factor': 857, 'weight_decay': 6.3385878057651125e-06, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:51:35,846] Trial 42 finished with value: 3.8775278275633087 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.015376888814585018, 'div_factor': 51, 'final_div_factor': 786, 'weight_decay': 8.441907464073777e-06, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:51:51,158] Trial 43 finished with value: 3.671466171555575 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0035287890439377845, 'div_factor': 46, 'final_div_factor': 743, 'weight_decay': 1.723160907293867e-06, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:52:04,730] Trial 44 finished with value: 3.7300475516880485 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.023956080336019776, 'div_factor': 40, 'final_div_factor': 687, 'weight_decay': 0.0002612410772046674, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:52:20,554] Trial 45 finished with value: 3.630021399232616 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.009326559811393872, 'div_factor': 80, 'final_div_factor': 964, 'weight_decay': 1.4864527139525808e-05, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:52:28,626] Trial 46 finished with value: 3.6970226371222736 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.004785130163532326, 'div_factor': 19, 'final_div_factor': 614, 'weight_decay': 0.003041733961656643, 'epochs': 100}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:52:43,070] Trial 47 finished with value: 3.8577499366034935 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0014913324585830918, 'div_factor': 66, 'final_div_factor': 858, 'weight_decay': 0.0004811049627029732, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:52:59,415] Trial 48 finished with value: 3.5068455916133474 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.01440595997353025, 'div_factor': 54, 'final_div_factor': 458, 'weight_decay': 7.772589079182869e-05, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.
# [I 2025-09-14 10:53:15,886] Trial 49 finished with value: 4.193936994451363 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.03664578996047875, 'div_factor': 76, 'final_div_factor': 948, 'weight_decay': 3.393374429049773e-05, 'epochs': 200}. Best is trial 39 with value: 3.259495435411628.

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 39, ValObjective: 3.2595
#
# Best Trial: 39
#   Best Score: 3.2595
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.010206934596553034
#     div_factor: 59
#     final_div_factor: 744
#     weight_decay: 7.501393203667051e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/IGTD/best_model/trial_39/best_model.pth
#   Seed 0: test_loss=10.129778, val_loss=16.677411, train_loss=7.032120
#
# Best Trial: 39
#   Best Score: 3.2595
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.010206934596553034
#     div_factor: 59
#     final_div_factor: 744
#     weight_decay: 7.501393203667051e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/IGTD/best_model/trial_39/best_model.pth
#   Seed 1: test_loss=16.714024, val_loss=12.716216, train_loss=29.437077
#
# Best Trial: 39
#   Best Score: 3.2595
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.010206934596553034
#     div_factor: 59
#     final_div_factor: 744
#     weight_decay: 7.501393203667051e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/IGTD/best_model/trial_39/best_model.pth
#   Seed 2: test_loss=13.002946, val_loss=13.503622, train_loss=22.440069
#
# Best Trial: 39
#   Best Score: 3.2595
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.010206934596553034
#     div_factor: 59
#     final_div_factor: 744
#     weight_decay: 7.501393203667051e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/IGTD/best_model/trial_39/best_model.pth
#   Seed 3: test_loss=16.672823, val_loss=14.124939, train_loss=25.563938
#
# Best Trial: 39
#   Best Score: 3.2595
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.010206934596553034
#     div_factor: 59
#     final_div_factor: 744
#     weight_decay: 7.501393203667051e-06
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/IGTD/best_model/trial_39/best_model.pth
#   Seed 4: test_loss=17.717830, val_loss=16.425130, train_loss=28.966067
#   → test_loss Mean ± Std: 14.847480 ± 3.190368
# Saved to: logs/Regression/boston/CNN_hybrid/IGTD/best_model/trial_39/best_results_mean.txt

# %% [markdown]
# ### REFINED

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"
name = f"REFINED"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/REFINED/train/regression.csv
# SyntheticImages/Regression/boston/REFINED/val/regression.csv
# SyntheticImages/Regression/boston/REFINED/test/regression.csv
# Images shape:  (3, 5, 5)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 5]

# %%
divisors = [1, 5]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-14 10:54:35,838] A new study created in memory with name: no-name-641181e4-9868-483b-a3c6-1472e1acd464
# [I 2025-09-14 10:54:59,469] Trial 0 finished with value: 3.9462554711203337 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.07421323692029864, 'div_factor': 45, 'final_div_factor': 490, 'weight_decay': 1.2961812726190303e-06, 'epochs': 200}. Best is trial 0 with value: 3.9462554711203337.
# [I 2025-09-14 10:55:13,386] Trial 1 finished with value: 3.9952279473921806 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.039462993712497584, 'div_factor': 83, 'final_div_factor': 341, 'weight_decay': 1.1850444158530227e-06, 'epochs': 200}. Best is trial 0 with value: 3.9462554711203337.
# [I 2025-09-14 10:55:20,681] Trial 2 finished with value: 3.715108033736239 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0019057204156479437, 'div_factor': 75, 'final_div_factor': 595, 'weight_decay': 0.00013941865286324208, 'epochs': 100}. Best is trial 2 with value: 3.715108033736239.
# [I 2025-09-14 10:55:33,020] Trial 3 finished with value: 3.472214489398399 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0004455310012304678, 'div_factor': 18, 'final_div_factor': 948, 'weight_decay': 8.049779369109221e-06, 'epochs': 200}. Best is trial 3 with value: 3.472214489398399.
# [I 2025-09-14 10:55:40,096] Trial 4 finished with value: 3.5608744342436727 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.016187568822403277, 'div_factor': 50, 'final_div_factor': 210, 'weight_decay': 2.3824307914184887e-05, 'epochs': 100}. Best is trial 3 with value: 3.472214489398399.
# [I 2025-09-14 10:55:51,192] Trial 5 finished with value: 3.8625514746140235 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.051560592334546726, 'div_factor': 57, 'final_div_factor': 366, 'weight_decay': 0.002121492213503578, 'epochs': 200}. Best is trial 3 with value: 3.472214489398399.
# [I 2025-09-14 10:55:59,433] Trial 6 finished with value: 3.5159170071872037 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0032306061216543394, 'div_factor': 30, 'final_div_factor': 835, 'weight_decay': 9.530786599352314e-05, 'epochs': 100}. Best is trial 3 with value: 3.472214489398399.
# [I 2025-09-14 10:56:07,723] Trial 7 finished with value: 4.092879574090571 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00015746642942615863, 'div_factor': 18, 'final_div_factor': 234, 'weight_decay': 1.4207627771797963e-06, 'epochs': 100}. Best is trial 3 with value: 3.472214489398399.
# [I 2025-09-14 10:56:22,202] Trial 8 finished with value: 3.351717147282596 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00017372941162831058, 'div_factor': 94, 'final_div_factor': 463, 'weight_decay': 0.0021255621165522523, 'epochs': 200}. Best is trial 8 with value: 3.351717147282596.
# [I 2025-09-14 10:56:36,285] Trial 9 finished with value: 3.5086364458094406 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00025847779792736444, 'div_factor': 87, 'final_div_factor': 136, 'weight_decay': 2.534993283574575e-06, 'epochs': 200}. Best is trial 8 with value: 3.351717147282596.
# [I 2025-09-14 10:56:49,773] Trial 10 finished with value: 3.1991404988426893 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0008822846351601476, 'div_factor': 94, 'final_div_factor': 668, 'weight_decay': 0.008404918928724924, 'epochs': 200}. Best is trial 10 with value: 3.1991404988426893.
# [I 2025-09-14 10:57:03,300] Trial 11 finished with value: 3.0520876384266424 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0008722801439717486, 'div_factor': 98, 'final_div_factor': 664, 'weight_decay': 0.00975169292205283, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:57:16,825] Trial 12 finished with value: 3.413472349370862 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0009969699553373068, 'div_factor': 100, 'final_div_factor': 731, 'weight_decay': 0.008961683291624518, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:57:30,410] Trial 13 finished with value: 3.256874297000485 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005374344294822908, 'div_factor': 71, 'final_div_factor': 665, 'weight_decay': 0.009867906550865032, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:57:43,291] Trial 14 finished with value: 3.42491523470716 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0007906722725704964, 'div_factor': 64, 'final_div_factor': 774, 'weight_decay': 0.0011802719380720624, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:57:57,096] Trial 15 finished with value: 3.198066252317395 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.010124844380076638, 'div_factor': 80, 'final_div_factor': 946, 'weight_decay': 0.0006016333670525277, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:58:10,855] Trial 16 finished with value: 3.183701140107835 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.009734553409443854, 'div_factor': 77, 'final_div_factor': 960, 'weight_decay': 0.0005932193376613778, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:58:23,750] Trial 17 finished with value: 3.121748949776732 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.015669613998705288, 'div_factor': 68, 'final_div_factor': 997, 'weight_decay': 0.0008910531976251717, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:58:30,610] Trial 18 finished with value: 3.256735497889021 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.019427820801492805, 'div_factor': 38, 'final_div_factor': 852, 'weight_decay': 0.0001626676166214196, 'epochs': 100}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:58:43,203] Trial 19 finished with value: 3.2207614576471553 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0025307882362413416, 'div_factor': 64, 'final_div_factor': 568, 'weight_decay': 0.003593055765443874, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:58:55,938] Trial 20 finished with value: 3.3675079547247218 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.005219206439625522, 'div_factor': 66, 'final_div_factor': 840, 'weight_decay': 0.0003561515306206581, 'epochs': 200}. Best is trial 11 with value: 3.0520876384266424.
# [I 2025-09-14 10:59:09,669] Trial 21 finished with value: 2.951766413061066 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00926620802289801, 'div_factor': 87, 'final_div_factor': 989, 'weight_decay': 0.0006205398683914304, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 10:59:22,413] Trial 22 finished with value: 3.3714315128082673 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0249409228813954, 'div_factor': 89, 'final_div_factor': 987, 'weight_decay': 6.356429226625654e-05, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 10:59:36,098] Trial 23 finished with value: 3.257262405314499 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.008537118041574842, 'div_factor': 95, 'final_div_factor': 885, 'weight_decay': 0.00038497632132111054, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 10:59:49,823] Trial 24 finished with value: 3.0301700516624783 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0018202922687561398, 'div_factor': 85, 'final_div_factor': 752, 'weight_decay': 0.003698462493108132, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:00:04,123] Trial 25 finished with value: 3.302390741104631 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0015909399345390301, 'div_factor': 99, 'final_div_factor': 742, 'weight_decay': 0.003293690663950843, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:00:17,735] Trial 26 finished with value: 3.4704756010115956 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00039770325851235747, 'div_factor': 86, 'final_div_factor': 648, 'weight_decay': 0.00425960378258399, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:00:24,734] Trial 27 finished with value: 3.292186712075724 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.003590387633390875, 'div_factor': 91, 'final_div_factor': 777, 'weight_decay': 0.0017427224514753661, 'epochs': 100}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:00:38,454] Trial 28 finished with value: 3.3092152846053584 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0015007685326587584, 'div_factor': 81, 'final_div_factor': 495, 'weight_decay': 0.004199168633597194, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:00:54,961] Trial 29 finished with value: 3.4512603005791256 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00045798923681814654, 'div_factor': 57, 'final_div_factor': 480, 'weight_decay': 0.00025651758992353363, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:01:08,567] Trial 30 finished with value: 3.337851482271222 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00010562985746534897, 'div_factor': 75, 'final_div_factor': 878, 'weight_decay': 0.0010685834078618891, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:01:21,367] Trial 31 finished with value: 3.3038725874027746 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.006353999146298698, 'div_factor': 85, 'final_div_factor': 923, 'weight_decay': 0.0009681117538535149, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:01:34,042] Trial 32 finished with value: 3.644215528217434 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.03804080846548966, 'div_factor': 70, 'final_div_factor': 999, 'weight_decay': 0.006128753774027213, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:01:46,727] Trial 33 finished with value: 3.0540786487617284 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0021510332633302436, 'div_factor': 81, 'final_div_factor': 764, 'weight_decay': 0.00214270087037136, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:02:02,444] Trial 34 finished with value: 4.232790266832644 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.09289674125569378, 'div_factor': 82, 'final_div_factor': 708, 'weight_decay': 0.0023599100173179294, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:02:16,739] Trial 35 finished with value: 3.3267776555853787 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0012918126935969536, 'div_factor': 92, 'final_div_factor': 622, 'weight_decay': 0.005436563103804744, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:02:24,598] Trial 36 finished with value: 3.418603735659464 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.002051122537117985, 'div_factor': 97, 'final_div_factor': 791, 'weight_decay': 0.002556308497760196, 'epochs': 100}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:02:38,305] Trial 37 finished with value: 3.1462033961485267 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0035150885509999596, 'div_factor': 89, 'final_div_factor': 554, 'weight_decay': 4.302354135742398e-05, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:02:45,586] Trial 38 finished with value: 3.3157253757135674 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0006940393988213437, 'div_factor': 48, 'final_div_factor': 699, 'weight_decay': 0.001314272077149336, 'epochs': 100}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:03:01,875] Trial 39 finished with value: 3.4028041103321622 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.002147682772061708, 'div_factor': 76, 'final_div_factor': 610, 'weight_decay': 0.0006133378966035858, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:03:16,299] Trial 40 finished with value: 3.228133366473306 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0004953283949040057, 'div_factor': 39, 'final_div_factor': 381, 'weight_decay': 2.1980611289885884e-05, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:03:28,882] Trial 41 finished with value: 3.4103097782772576 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.02955815920800693, 'div_factor': 71, 'final_div_factor': 909, 'weight_decay': 0.0016676925090267465, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:03:41,502] Trial 42 finished with value: 3.1225038859188188 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.015718171674718482, 'div_factor': 82, 'final_div_factor': 843, 'weight_decay': 0.0008500000615050108, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:03:54,133] Trial 43 finished with value: 3.224937935165411 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.01376553629814639, 'div_factor': 62, 'final_div_factor': 805, 'weight_decay': 0.005131712840497936, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:04:06,711] Trial 44 finished with value: 3.090404358365676 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0011684112263311223, 'div_factor': 11, 'final_div_factor': 916, 'weight_decay': 0.00023669189938430385, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:04:20,287] Trial 45 finished with value: 2.9687636525693475 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.001127965718641253, 'div_factor': 10, 'final_div_factor': 759, 'weight_decay': 0.00021087262862910035, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:04:28,029] Trial 46 finished with value: 3.328392770230455 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0006248940394761627, 'div_factor': 25, 'final_div_factor': 748, 'weight_decay': 0.0001617156167357397, 'epochs': 100}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:04:44,332] Trial 47 finished with value: 3.455015605664927 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0003060785887087732, 'div_factor': 52, 'final_div_factor': 692, 'weight_decay': 0.007895478253445809, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:04:58,754] Trial 48 finished with value: 3.2334249824303014 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.002641147291663963, 'div_factor': 28, 'final_div_factor': 423, 'weight_decay': 9.822277686745393e-05, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.
# [I 2025-09-14 11:05:12,313] Trial 49 finished with value: 3.304337286823234 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0010050688608436108, 'div_factor': 100, 'final_div_factor': 277, 'weight_decay': 0.0004272555526787999, 'epochs': 200}. Best is trial 21 with value: 2.951766413061066.

# %%
best_trial.params
# Out:
# {'model': 'model1',
#  'mlp_hidden_dims': '[128, 64, 32]',
#  'fusion_hidden_dims': '[256, 128, 64]',
#  'max_lr': 0.010206934596553034,
#  'div_factor': 59,
#  'final_div_factor': 744,
#  'weight_decay': 7.501393203667051e-06,
#  'epochs': 200}

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 21, ValObjective: 2.9518
#
# Best Trial: 21
#   Best Score: 2.9518
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.00926620802289801
#     div_factor: 87
#     final_div_factor: 989
#     weight_decay: 0.0006205398683914304
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/REFINED/best_model/trial_21/best_model.pth
#   Seed 0: test_loss=5.454566, val_loss=10.339561, train_loss=1.648208
#
# Best Trial: 21
#   Best Score: 2.9518
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.00926620802289801
#     div_factor: 87
#     final_div_factor: 989
#     weight_decay: 0.0006205398683914304
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/REFINED/best_model/trial_21/best_model.pth
#   Seed 1: test_loss=4.963115, val_loss=10.290258, train_loss=1.379813
#
# Best Trial: 21
#   Best Score: 2.9518
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.00926620802289801
#     div_factor: 87
#     final_div_factor: 989
#     weight_decay: 0.0006205398683914304
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/REFINED/best_model/trial_21/best_model.pth
#   Seed 2: test_loss=6.482896, val_loss=11.043166, train_loss=3.188097
#
# Best Trial: 21
#   Best Score: 2.9518
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.00926620802289801
#     div_factor: 87
#     final_div_factor: 989
#     weight_decay: 0.0006205398683914304
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/REFINED/best_model/trial_21/best_model.pth
#   Seed 3: test_loss=5.759218, val_loss=10.814064, train_loss=1.525482
#
# Best Trial: 21
#   Best Score: 2.9518
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.00926620802289801
#     div_factor: 87
#     final_div_factor: 989
#     weight_decay: 0.0006205398683914304
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/REFINED/best_model/trial_21/best_model.pth
#   Seed 4: test_loss=6.987590, val_loss=10.620546, train_loss=5.406569
#   → test_loss Mean ± Std: 5.929477 ± 0.808434
# Saved to: logs/Regression/boston/CNN_hybrid/REFINED/best_model/trial_21/best_results_mean.txt

# %% [markdown]
# ### EXPERIMENT: BarGraph

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"

name = f"BarGraph"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/BarGraph/train/regression.csv
# SyntheticImages/Regression/boston/BarGraph/val/regression.csv
# SyntheticImages/Regression/boston/BarGraph/test/regression.csv
# Images shape:  (3, 22, 22)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 2, 11, 22]

# %%
divisors = [2, 11, 22]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-14 11:06:20,877] A new study created in memory with name: no-name-6037fe66-4140-4a6c-a9dc-add176f5ab23
# [I 2025-09-14 11:06:28,296] Trial 0 finished with value: 3.232899647234562 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0027462098495296574, 'div_factor': 83, 'final_div_factor': 147, 'weight_decay': 0.004282533984619644, 'epochs': 100}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:06:44,868] Trial 1 finished with value: 4.037967024208919 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.05971308088854196, 'div_factor': 97, 'final_div_factor': 838, 'weight_decay': 0.0018126455400841986, 'epochs': 200}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:06:52,154] Trial 2 finished with value: 3.2910033092777717 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0005755087840346499, 'div_factor': 49, 'final_div_factor': 353, 'weight_decay': 0.007991462078221033, 'epochs': 100}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:07:08,725] Trial 3 finished with value: 3.535785833958704 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00033131876648115994, 'div_factor': 34, 'final_div_factor': 182, 'weight_decay': 5.077339109580839e-05, 'epochs': 200}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:07:25,347] Trial 4 finished with value: 3.500575971895163 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00992033955825265, 'div_factor': 22, 'final_div_factor': 384, 'weight_decay': 0.0002973450084367277, 'epochs': 200}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:07:32,688] Trial 5 finished with value: 3.284553536046009 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0007321960084532122, 'div_factor': 24, 'final_div_factor': 151, 'weight_decay': 2.5703200572563156e-06, 'epochs': 100}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:07:41,353] Trial 6 finished with value: 3.468808972656427 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00548741972696882, 'div_factor': 61, 'final_div_factor': 670, 'weight_decay': 4.8603761400696996e-05, 'epochs': 100}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:07:48,353] Trial 7 finished with value: 3.4471421000797298 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.02999708724866151, 'div_factor': 100, 'final_div_factor': 902, 'weight_decay': 0.002914103658886569, 'epochs': 100}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:08:05,008] Trial 8 finished with value: 3.3659301676133317 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.004342005371272709, 'div_factor': 96, 'final_div_factor': 764, 'weight_decay': 0.000250373433161781, 'epochs': 200}. Best is trial 0 with value: 3.232899647234562.
# [I 2025-09-14 11:08:20,339] Trial 9 finished with value: 3.1542394296239675 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0007196824413134619, 'div_factor': 71, 'final_div_factor': 494, 'weight_decay': 0.00021342039917361782, 'epochs': 200}. Best is trial 9 with value: 3.1542394296239675.
# [I 2025-09-14 11:08:35,426] Trial 10 finished with value: 3.326846024743417 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00010777189856999324, 'div_factor': 68, 'final_div_factor': 524, 'weight_decay': 3.886283842467014e-06, 'epochs': 200}. Best is trial 9 with value: 3.1542394296239675.
# [I 2025-09-14 11:08:42,793] Trial 11 finished with value: 3.0262332577657847 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.001444794791343585, 'div_factor': 76, 'final_div_factor': 366, 'weight_decay': 0.0014625199666976185, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:08:50,682] Trial 12 finished with value: 3.340544688416489 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0012376796034671862, 'div_factor': 74, 'final_div_factor': 476, 'weight_decay': 0.0005798505723059013, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:09:05,159] Trial 13 finished with value: 3.3246272516335855 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00016509702257565517, 'div_factor': 50, 'final_div_factor': 329, 'weight_decay': 1.8302301865962143e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:09:12,284] Trial 14 finished with value: 3.3546418668844087 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0017293334161287235, 'div_factor': 82, 'final_div_factor': 635, 'weight_decay': 0.0009025264309438286, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:09:27,734] Trial 15 finished with value: 3.2055076111444474 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00030056869070079536, 'div_factor': 81, 'final_div_factor': 277, 'weight_decay': 0.00014524518729649871, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:09:42,060] Trial 16 finished with value: 3.442819259787886 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.008275783659255041, 'div_factor': 57, 'final_div_factor': 616, 'weight_decay': 1.7616763679657257e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:09:49,619] Trial 17 finished with value: 3.289055686091888 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.001013937894114939, 'div_factor': 39, 'final_div_factor': 455, 'weight_decay': 0.0005193800321866626, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:09:57,200] Trial 18 finished with value: 3.4768251469871427 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.015178865357130013, 'div_factor': 67, 'final_div_factor': 229, 'weight_decay': 0.0013232945984176475, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:10:11,742] Trial 19 finished with value: 3.240427150590819 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0024617372129745476, 'div_factor': 87, 'final_div_factor': 982, 'weight_decay': 4.528309584144641e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:10:27,434] Trial 20 finished with value: 3.4138099699224895 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0004574392465451286, 'div_factor': 75, 'final_div_factor': 455, 'weight_decay': 0.008876117112750192, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:10:42,311] Trial 21 finished with value: 3.04563949183839 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00022657478783534118, 'div_factor': 75, 'final_div_factor': 271, 'weight_decay': 0.00013784261797288673, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:10:57,603] Trial 22 finished with value: 3.212917636189648 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00019985610645881528, 'div_factor': 67, 'final_div_factor': 272, 'weight_decay': 0.00012983121173094388, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:11:13,052] Trial 23 finished with value: 3.2889205648282975 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.001198440358911908, 'div_factor': 90, 'final_div_factor': 375, 'weight_decay': 0.0002398180615864242, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:11:28,452] Trial 24 finished with value: 3.153619104088875 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.000255565399551662, 'div_factor': 75, 'final_div_factor': 574, 'weight_decay': 1.8971162255225537e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:11:42,959] Trial 25 finished with value: 3.2005439593993024 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0001060624061912688, 'div_factor': 61, 'final_div_factor': 716, 'weight_decay': 7.606560622643125e-06, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:11:51,559] Trial 26 finished with value: 3.6061910482311905 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00025110371630589716, 'div_factor': 12, 'final_div_factor': 584, 'weight_decay': 8.226002514317551e-06, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:12:06,980] Trial 27 finished with value: 3.150479622309266 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.000406656635129347, 'div_factor': 79, 'final_div_factor': 411, 'weight_decay': 7.268178480600723e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:12:14,405] Trial 28 finished with value: 3.4103423567039717 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00042090881583160903, 'div_factor': 91, 'final_div_factor': 292, 'weight_decay': 8.296499246473176e-05, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:12:21,889] Trial 29 finished with value: 3.3831309109221612 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0025855008153787113, 'div_factor': 80, 'final_div_factor': 106, 'weight_decay': 0.002923609428464146, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:12:36,668] Trial 30 finished with value: 3.379376858258676 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.001767588699903292, 'div_factor': 86, 'final_div_factor': 414, 'weight_decay': 0.0005604782069695845, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:12:52,091] Trial 31 finished with value: 3.237873194331551 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00018712177084577258, 'div_factor': 77, 'final_div_factor': 547, 'weight_decay': 1.892903460476728e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:13:07,397] Trial 32 finished with value: 3.1328039763755617 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0003504632163105222, 'div_factor': 61, 'final_div_factor': 216, 'weight_decay': 2.5170921837655002e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:13:22,622] Trial 33 finished with value: 3.156921164281394 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.000541845802842433, 'div_factor': 62, 'final_div_factor': 231, 'weight_decay': 1.0226099707256973e-06, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:13:39,317] Trial 34 finished with value: 3.683472583837011 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00014642386789247508, 'div_factor': 52, 'final_div_factor': 208, 'weight_decay': 6.948778064873208e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:13:54,808] Trial 35 finished with value: 3.4820202453042253 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0007953126962277459, 'div_factor': 42, 'final_div_factor': 327, 'weight_decay': 3.201589516837641e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:14:10,017] Trial 36 finished with value: 3.295843170832932 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00033170202687519604, 'div_factor': 65, 'final_div_factor': 415, 'weight_decay': 3.185435744311274e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:14:18,401] Trial 37 finished with value: 3.545839536656214 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0004300696183111871, 'div_factor': 56, 'final_div_factor': 157, 'weight_decay': 8.563759798061633e-06, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:14:32,910] Trial 38 finished with value: 3.334976665409472 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0009593183443521298, 'div_factor': 44, 'final_div_factor': 357, 'weight_decay': 0.005370636420654274, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:14:41,404] Trial 39 finished with value: 3.4377041842767317 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0017307653253586049, 'div_factor': 94, 'final_div_factor': 105, 'weight_decay': 0.00011070988213474111, 'epochs': 100}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:14:55,749] Trial 40 finished with value: 3.63767551903172 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0006330962241824327, 'div_factor': 72, 'final_div_factor': 190, 'weight_decay': 0.0003712953784582646, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:15:11,174] Trial 41 finished with value: 3.120694207696688 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00026236466339917946, 'div_factor': 77, 'final_div_factor': 306, 'weight_decay': 3.348404298429487e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:15:26,650] Trial 42 finished with value: 3.5591550147823696 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0942892421107868, 'div_factor': 85, 'final_div_factor': 305, 'weight_decay': 3.391680263722394e-05, 'epochs': 200}. Best is trial 11 with value: 3.0262332577657847.
# [I 2025-09-14 11:15:41,924] Trial 43 finished with value: 2.9736026655902057 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0003684298952007884, 'div_factor': 78, 'final_div_factor': 242, 'weight_decay': 6.0435502226795816e-05, 'epochs': 200}. Best is trial 43 with value: 2.9736026655902057.
# [I 2025-09-14 11:15:57,021] Trial 44 finished with value: 3.3428394824855205 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0001372003996966434, 'div_factor': 71, 'final_div_factor': 252, 'weight_decay': 1.2465856518937435e-05, 'epochs': 200}. Best is trial 43 with value: 2.9736026655902057.
# [I 2025-09-14 11:16:12,396] Trial 45 finished with value: 3.0776060025066623 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00022757420162949432, 'div_factor': 62, 'final_div_factor': 177, 'weight_decay': 4.4079905685453356e-06, 'epochs': 200}. Best is trial 43 with value: 2.9736026655902057.
# [I 2025-09-14 11:16:27,774] Trial 46 finished with value: 3.2964341289200054 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00022256469838896834, 'div_factor': 70, 'final_div_factor': 152, 'weight_decay': 3.4434746916418785e-06, 'epochs': 200}. Best is trial 43 with value: 2.9736026655902057.
# [I 2025-09-14 11:16:36,022] Trial 47 finished with value: 3.4789659057683413 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0001301805749940111, 'div_factor': 100, 'final_div_factor': 178, 'weight_decay': 1.4704708369612225e-06, 'epochs': 100}. Best is trial 43 with value: 2.9736026655902057.
# [I 2025-09-14 11:16:51,430] Trial 48 finished with value: 3.4623780707639695 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0042776767756210156, 'div_factor': 78, 'final_div_factor': 252, 'weight_decay': 0.00016878754905358195, 'epochs': 200}. Best is trial 43 with value: 2.9736026655902057.
# [I 2025-09-14 11:17:05,882] Trial 49 finished with value: 3.1923728048845126 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00028414531074538295, 'div_factor': 82, 'final_div_factor': 316, 'weight_decay': 0.0012188022583941042, 'epochs': 200}. Best is trial 43 with value: 2.9736026655902057.

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 43, ValObjective: 2.9736
#
# Best Trial: 43
#   Best Score: 2.9736
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0003684298952007884
#     div_factor: 78
#     final_div_factor: 242
#     weight_decay: 6.0435502226795816e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BarGraph/best_model/trial_43/best_model.pth
#   Seed 0: test_loss=6.044407, val_loss=10.498914, train_loss=3.260387
#
# Best Trial: 43
#   Best Score: 2.9736
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0003684298952007884
#     div_factor: 78
#     final_div_factor: 242
#     weight_decay: 6.0435502226795816e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BarGraph/best_model/trial_43/best_model.pth
#   Seed 1: test_loss=8.423077, val_loss=10.709731, train_loss=4.821782
#
# Best Trial: 43
#   Best Score: 2.9736
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0003684298952007884
#     div_factor: 78
#     final_div_factor: 242
#     weight_decay: 6.0435502226795816e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BarGraph/best_model/trial_43/best_model.pth
#   Seed 2: test_loss=7.731713, val_loss=10.149500, train_loss=4.343783
#
# Best Trial: 43
#   Best Score: 2.9736
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0003684298952007884
#     div_factor: 78
#     final_div_factor: 242
#     weight_decay: 6.0435502226795816e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BarGraph/best_model/trial_43/best_model.pth
#   Seed 3: test_loss=8.090692, val_loss=11.439282, train_loss=0.877988
#
# Best Trial: 43
#   Best Score: 2.9736
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.0003684298952007884
#     div_factor: 78
#     final_div_factor: 242
#     weight_decay: 6.0435502226795816e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BarGraph/best_model/trial_43/best_model.pth
#   Seed 4: test_loss=9.752351, val_loss=10.448255, train_loss=5.149136
#   → test_loss Mean ± Std: 8.008448 ± 1.337340
# Saved to: logs/Regression/boston/CNN_hybrid/BarGraph/best_model/trial_43/best_results_mean.txt

# %% [markdown]
# ### EXPERIMENT: DistanceMatrix

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"

name = f"DistanceMatrix"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/DistanceMatrix/train/regression.csv
# SyntheticImages/Regression/boston/DistanceMatrix/val/regression.csv
# SyntheticImages/Regression/boston/DistanceMatrix/test/regression.csv
# Images shape:  (3, 22, 22)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 2, 11, 22]

# %%
divisors = [2, 11, 22]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-14 11:18:25,064] A new study created in memory with name: no-name-9c20f77f-71b0-4174-b5dc-d9690cc7641b
# [I 2025-09-14 11:18:32,621] Trial 0 finished with value: 3.9298115098319433 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0048037538022195365, 'div_factor': 96, 'final_div_factor': 688, 'weight_decay': 0.001580949470005536, 'epochs': 100}. Best is trial 0 with value: 3.9298115098319433.
# [I 2025-09-14 11:18:40,630] Trial 1 finished with value: 3.5240124827498356 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.034493874705165205, 'div_factor': 24, 'final_div_factor': 883, 'weight_decay': 0.0001598757945559384, 'epochs': 100}. Best is trial 1 with value: 3.5240124827498356.
# [I 2025-09-14 11:18:57,124] Trial 2 finished with value: 3.4139011790136515 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00047128953595541683, 'div_factor': 80, 'final_div_factor': 410, 'weight_decay': 9.195811554101035e-06, 'epochs': 200}. Best is trial 2 with value: 3.4139011790136515.
# [I 2025-09-14 11:19:12,077] Trial 3 finished with value: 4.23761560513052 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.031102173172054385, 'div_factor': 36, 'final_div_factor': 875, 'weight_decay': 0.0001447867569959827, 'epochs': 200}. Best is trial 2 with value: 3.4139011790136515.
# [I 2025-09-14 11:19:20,467] Trial 4 finished with value: 3.606940038501502 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00013287217237830968, 'div_factor': 50, 'final_div_factor': 353, 'weight_decay': 6.64846589542724e-05, 'epochs': 100}. Best is trial 2 with value: 3.4139011790136515.
# [I 2025-09-14 11:19:37,340] Trial 5 finished with value: 3.4895025595051465 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0007270271591043824, 'div_factor': 78, 'final_div_factor': 360, 'weight_decay': 1.1752611740319305e-05, 'epochs': 200}. Best is trial 2 with value: 3.4139011790136515.
# [I 2025-09-14 11:19:45,786] Trial 6 finished with value: 3.581997437561925 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.003676860259808805, 'div_factor': 13, 'final_div_factor': 538, 'weight_decay': 0.0005514377836126211, 'epochs': 100}. Best is trial 2 with value: 3.4139011790136515.
# [I 2025-09-14 11:20:00,739] Trial 7 finished with value: 3.3354764883350385 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0002607608089121944, 'div_factor': 42, 'final_div_factor': 810, 'weight_decay': 9.214127565101907e-05, 'epochs': 200}. Best is trial 7 with value: 3.3354764883350385.
# [I 2025-09-14 11:20:14,942] Trial 8 finished with value: 3.261459102689412 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0005474886497391307, 'div_factor': 76, 'final_div_factor': 410, 'weight_decay': 0.00038809494208560003, 'epochs': 200}. Best is trial 8 with value: 3.261459102689412.
# [I 2025-09-14 11:20:29,860] Trial 9 finished with value: 3.1797203418432165 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0007963190674188467, 'div_factor': 21, 'final_div_factor': 932, 'weight_decay': 0.0009009590161594901, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:20:44,534] Trial 10 finished with value: 3.4687057354826334 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0016396531203897945, 'div_factor': 15, 'final_div_factor': 115, 'weight_decay': 0.009244613469005226, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:20:58,298] Trial 11 finished with value: 3.5176182500487703 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0013597503645043382, 'div_factor': 65, 'final_div_factor': 997, 'weight_decay': 0.0022578807460627037, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:21:12,598] Trial 12 finished with value: 3.3351333685291307 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00791931266744328, 'div_factor': 65, 'final_div_factor': 581, 'weight_decay': 0.0007331654101086627, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:21:26,494] Trial 13 finished with value: 3.516285473983291 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00013417912694859959, 'div_factor': 95, 'final_div_factor': 182, 'weight_decay': 0.008399374830071537, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:21:40,760] Trial 14 finished with value: 3.598172857944628 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0005371343857621195, 'div_factor': 61, 'final_div_factor': 650, 'weight_decay': 2.6577887869844314e-06, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:21:56,440] Trial 15 finished with value: 3.60445607223339 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.014544407978774742, 'div_factor': 32, 'final_div_factor': 474, 'weight_decay': 0.0004931310363235045, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:22:10,945] Trial 16 finished with value: 4.185448215049884 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.09870687508931648, 'div_factor': 80, 'final_div_factor': 232, 'weight_decay': 3.0070340660997602e-05, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:22:25,358] Trial 17 finished with value: 3.418933178668486 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.001738624180932448, 'div_factor': 49, 'final_div_factor': 734, 'weight_decay': 0.002911728821644102, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:22:32,869] Trial 18 finished with value: 3.392931738011921 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0003652970714794852, 'div_factor': 24, 'final_div_factor': 316, 'weight_decay': 0.0004942193326370012, 'epochs': 100}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:22:48,379] Trial 19 finished with value: 3.3673996294295434 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0008879204132453522, 'div_factor': 70, 'final_div_factor': 991, 'weight_decay': 0.0003143535029850713, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:23:02,679] Trial 20 finished with value: 3.441405002970475 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0002651700610233343, 'div_factor': 88, 'final_div_factor': 496, 'weight_decay': 0.0012977852394345088, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:23:17,047] Trial 21 finished with value: 3.6095170162384798 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.008469597082292021, 'div_factor': 58, 'final_div_factor': 629, 'weight_decay': 0.0009353507539829588, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:23:31,384] Trial 22 finished with value: 3.3649997197642785 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0026944761557221694, 'div_factor': 71, 'final_div_factor': 593, 'weight_decay': 0.0002517132351524943, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:23:45,783] Trial 23 finished with value: 3.6817275302657446 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0070154428650320184, 'div_factor': 55, 'final_div_factor': 741, 'weight_decay': 0.0038681148829326087, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:24:00,230] Trial 24 finished with value: 3.25098785645943 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0009230014641127394, 'div_factor': 71, 'final_div_factor': 435, 'weight_decay': 0.0010536385798944046, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:24:15,081] Trial 25 finished with value: 3.1930244293473065 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0009654413363257412, 'div_factor': 87, 'final_div_factor': 421, 'weight_decay': 0.0045130275319251005, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:24:22,749] Trial 26 finished with value: 3.514087391617182 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0025585627557986566, 'div_factor': 87, 'final_div_factor': 267, 'weight_decay': 0.003426519836415901, 'epochs': 100}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:24:39,279] Trial 27 finished with value: 3.5470840459717063 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0010497859288290366, 'div_factor': 89, 'final_div_factor': 451, 'weight_decay': 0.003749293614241949, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:24:54,591] Trial 28 finished with value: 3.467685708021518 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0002753676220558155, 'div_factor': 100, 'final_div_factor': 518, 'weight_decay': 0.006071574817071436, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:25:02,504] Trial 29 finished with value: 3.644619432631591 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.004416390433861446, 'div_factor': 94, 'final_div_factor': 681, 'weight_decay': 0.0014082610070952903, 'epochs': 100}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:25:17,398] Trial 30 finished with value: 3.2561527113191655 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0018287110201425207, 'div_factor': 72, 'final_div_factor': 416, 'weight_decay': 0.0013131275634125376, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:25:32,172] Trial 31 finished with value: 3.4513680661906103 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.001971563739799224, 'div_factor': 72, 'final_div_factor': 432, 'weight_decay': 0.0019468645865065976, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:25:46,702] Trial 32 finished with value: 3.2327894664476684 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.000995410179748185, 'div_factor': 84, 'final_div_factor': 304, 'weight_decay': 0.0010967615499007607, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:26:01,346] Trial 33 finished with value: 3.292147315621509 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0009648263374193518, 'div_factor': 88, 'final_div_factor': 305, 'weight_decay': 0.00020908816538726266, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:26:17,784] Trial 34 finished with value: 3.35432473199209 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0005842673276658328, 'div_factor': 82, 'final_div_factor': 204, 'weight_decay': 0.005588877883297381, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:26:25,522] Trial 35 finished with value: 3.273637351260576 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0012153402515257892, 'div_factor': 84, 'final_div_factor': 367, 'weight_decay': 0.000907511607082911, 'epochs': 100}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:26:42,012] Trial 36 finished with value: 3.5020842477107776 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0008133881734820449, 'div_factor': 92, 'final_div_factor': 922, 'weight_decay': 3.7488880301728245e-05, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:26:56,541] Trial 37 finished with value: 3.230089822707156 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00018640991630708282, 'div_factor': 99, 'final_div_factor': 297, 'weight_decay': 0.002052960174279022, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:27:05,081] Trial 38 finished with value: 3.4053328092938613 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00018076604701468233, 'div_factor': 23, 'final_div_factor': 126, 'weight_decay': 0.002023906416625525, 'epochs': 100}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:27:20,397] Trial 39 finished with value: 3.3428859842195053 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0003809097820308508, 'div_factor': 100, 'final_div_factor': 288, 'weight_decay': 0.00016051480880352898, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:27:35,108] Trial 40 finished with value: 3.3568991830622705 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00011182425126168956, 'div_factor': 32, 'final_div_factor': 366, 'weight_decay': 0.005657224169895864, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:27:49,937] Trial 41 finished with value: 3.4846507420934683 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0001876833470644352, 'div_factor': 83, 'final_div_factor': 346, 'weight_decay': 0.0007186085298857925, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:28:04,850] Trial 42 finished with value: 3.1886270064048134 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0006996405634412929, 'div_factor': 78, 'final_div_factor': 261, 'weight_decay': 0.001204751077005253, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:28:19,646] Trial 43 finished with value: 3.4502476921176095 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.000390619900211609, 'div_factor': 77, 'final_div_factor': 169, 'weight_decay': 0.0022736800644418604, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:28:34,609] Trial 44 finished with value: 3.396699728563081 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.000646265367909715, 'div_factor': 93, 'final_div_factor': 217, 'weight_decay': 9.692994295544968e-05, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:28:49,570] Trial 45 finished with value: 3.4152567365661044 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0002147899055885786, 'div_factor': 97, 'final_div_factor': 276, 'weight_decay': 0.0016629395012920812, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:29:05,141] Trial 46 finished with value: 3.2853659836160216 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0004891743901919924, 'div_factor': 43, 'final_div_factor': 252, 'weight_decay': 0.0003790888511011976, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:29:21,631] Trial 47 finished with value: 3.2693301267758565 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0013166895112792414, 'div_factor': 77, 'final_div_factor': 330, 'weight_decay': 1.3604849656056664e-06, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:29:36,472] Trial 48 finished with value: 3.3567385241618517 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0006622668347841159, 'div_factor': 65, 'final_div_factor': 381, 'weight_decay': 0.008278486326957477, 'epochs': 200}. Best is trial 9 with value: 3.1797203418432165.
# [I 2025-09-14 11:29:43,970] Trial 49 finished with value: 3.665159406955386 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0001450510750586336, 'div_factor': 48, 'final_div_factor': 813, 'weight_decay': 0.000657537246466574, 'epochs': 100}. Best is trial 9 with value: 3.1797203418432165.

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 9, ValObjective: 3.1797
#
# Best Trial: 9
#   Best Score: 3.1797
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.0007963190674188467
#     div_factor: 21
#     final_div_factor: 932
#     weight_decay: 0.0009009590161594901
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/DistanceMatrix/best_model/trial_9/best_model.pth
#   Seed 0: test_loss=8.082563, val_loss=10.814391, train_loss=4.625947
#
# Best Trial: 9
#   Best Score: 3.1797
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.0007963190674188467
#     div_factor: 21
#     final_div_factor: 932
#     weight_decay: 0.0009009590161594901
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/DistanceMatrix/best_model/trial_9/best_model.pth
#   Seed 1: test_loss=7.405877, val_loss=11.468610, train_loss=4.305085
#
# Best Trial: 9
#   Best Score: 3.1797
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.0007963190674188467
#     div_factor: 21
#     final_div_factor: 932
#     weight_decay: 0.0009009590161594901
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/DistanceMatrix/best_model/trial_9/best_model.pth
#   Seed 2: test_loss=7.659428, val_loss=11.153059, train_loss=5.280767
#
# Best Trial: 9
#   Best Score: 3.1797
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.0007963190674188467
#     div_factor: 21
#     final_div_factor: 932
#     weight_decay: 0.0009009590161594901
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/DistanceMatrix/best_model/trial_9/best_model.pth
#   Seed 3: test_loss=7.494430, val_loss=11.493891, train_loss=1.945669
#
# Best Trial: 9
#   Best Score: 3.1797
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.0007963190674188467
#     div_factor: 21
#     final_div_factor: 932
#     weight_decay: 0.0009009590161594901
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/DistanceMatrix/best_model/trial_9/best_model.pth
#   Seed 4: test_loss=6.723253, val_loss=11.277400, train_loss=3.368231
#   → test_loss Mean ± Std: 7.473110 ± 0.493307
# Saved to: logs/Regression/boston/CNN_hybrid/DistanceMatrix/best_model/trial_9/best_results_mean.txt

# %% [markdown]
# ### EXPERIMENT: Combination

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"

name = f"Combination"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/Combination/train/regression.csv
# SyntheticImages/Regression/boston/Combination/val/regression.csv
# SyntheticImages/Regression/boston/Combination/test/regression.csv
# Images shape:  (3, 22, 22)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 2, 11, 22]

# %%
divisors = [2, 11, 22]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-14 11:31:02,194] A new study created in memory with name: no-name-3238a7e3-293f-4954-a139-1eeaf9e71c58
# [I 2025-09-14 11:31:14,333] Trial 0 finished with value: 3.406160965902047 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.005921090196946735, 'div_factor': 10, 'final_div_factor': 609, 'weight_decay': 1.299594428056685e-06, 'epochs': 200}. Best is trial 0 with value: 3.406160965902047.
# [I 2025-09-14 11:31:20,623] Trial 1 finished with value: 3.239411491587417 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.001744237368750976, 'div_factor': 64, 'final_div_factor': 305, 'weight_decay': 0.009223875849562151, 'epochs': 100}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:31:27,867] Trial 2 finished with value: 3.4398518233212094 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0035915255318009764, 'div_factor': 42, 'final_div_factor': 776, 'weight_decay': 2.026262787608938e-05, 'epochs': 100}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:31:36,046] Trial 3 finished with value: 4.11852611807354 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.04224317276256314, 'div_factor': 62, 'final_div_factor': 238, 'weight_decay': 0.007426870315994289, 'epochs': 100}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:31:52,632] Trial 4 finished with value: 3.836795376878742 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.024560230515899315, 'div_factor': 41, 'final_div_factor': 416, 'weight_decay': 3.947690710810021e-05, 'epochs': 200}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:32:09,272] Trial 5 finished with value: 3.6846675015756807 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.05251490811599579, 'div_factor': 73, 'final_div_factor': 292, 'weight_decay': 0.000526952030597098, 'epochs': 200}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:32:25,725] Trial 6 finished with value: 4.006356672036245 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.07952643426664839, 'div_factor': 91, 'final_div_factor': 151, 'weight_decay': 0.00017209450984794107, 'epochs': 200}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:32:34,046] Trial 7 finished with value: 3.33445431615847 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0010588990999831974, 'div_factor': 91, 'final_div_factor': 770, 'weight_decay': 0.0018461267624225815, 'epochs': 100}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:32:49,098] Trial 8 finished with value: 3.328108523332527 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0017237435036671872, 'div_factor': 18, 'final_div_factor': 619, 'weight_decay': 3.286826800613123e-05, 'epochs': 200}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:32:57,142] Trial 9 finished with value: 3.4035453207541173 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0007801178318151542, 'div_factor': 35, 'final_div_factor': 396, 'weight_decay': 0.0005298166181623193, 'epochs': 100}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:33:04,908] Trial 10 finished with value: 3.25196118969533 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00011625770675889197, 'div_factor': 72, 'final_div_factor': 974, 'weight_decay': 0.008727809653658561, 'epochs': 100}. Best is trial 1 with value: 3.239411491587417.
# [I 2025-09-14 11:33:12,698] Trial 11 finished with value: 3.172537748504505 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00011149775372244271, 'div_factor': 70, 'final_div_factor': 972, 'weight_decay': 0.00611285297227024, 'epochs': 100}. Best is trial 11 with value: 3.172537748504505.
# [I 2025-09-14 11:33:20,241] Trial 12 finished with value: 3.127100886821508 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0001245709795332683, 'div_factor': 61, 'final_div_factor': 938, 'weight_decay': 0.002485821352329181, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:33:27,950] Trial 13 finished with value: 3.2040485818349103 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00010347542134861115, 'div_factor': 82, 'final_div_factor': 966, 'weight_decay': 0.0017617430467481569, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:33:35,634] Trial 14 finished with value: 3.2110257101820587 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0003153897390922711, 'div_factor': 51, 'final_div_factor': 821, 'weight_decay': 0.0012364862851935918, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:33:43,174] Trial 15 finished with value: 3.212796974556475 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00023226700706288647, 'div_factor': 55, 'final_div_factor': 871, 'weight_decay': 0.0030916970076830226, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:33:50,826] Trial 16 finished with value: 3.419790948423662 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0003249312659377208, 'div_factor': 78, 'final_div_factor': 688, 'weight_decay': 0.00020735146816708343, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:33:58,443] Trial 17 finished with value: 3.4924482892521955 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.009772365209879726, 'div_factor': 98, 'final_div_factor': 899, 'weight_decay': 0.0005660405298005095, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:34:05,723] Trial 18 finished with value: 3.1585825242214103 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0005808054274014723, 'div_factor': 29, 'final_div_factor': 504, 'weight_decay': 6.980715299930079e-06, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:34:13,166] Trial 19 finished with value: 3.301687190765361 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0005521671684040619, 'div_factor': 27, 'final_div_factor': 503, 'weight_decay': 3.7301642335686285e-06, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:34:20,403] Trial 20 finished with value: 3.2652018149658155 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00022364953153261862, 'div_factor': 27, 'final_div_factor': 492, 'weight_decay': 9.599418365251438e-06, 'epochs': 100}. Best is trial 12 with value: 3.127100886821508.
# [I 2025-09-14 11:34:27,785] Trial 21 finished with value: 3.1066700273367367 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0001401019942323959, 'div_factor': 63, 'final_div_factor': 688, 'weight_decay': 0.003987354905121441, 'epochs': 100}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:34:35,251] Trial 22 finished with value: 3.365699244453338 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0001960467781946206, 'div_factor': 49, 'final_div_factor': 691, 'weight_decay': 8.039355890871313e-05, 'epochs': 100}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:34:42,854] Trial 23 finished with value: 3.253149120816706 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0005452976896849998, 'div_factor': 60, 'final_div_factor': 570, 'weight_decay': 5.154766483000924e-06, 'epochs': 100}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:34:50,291] Trial 24 finished with value: 3.3386303934019947 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0003847642910454791, 'div_factor': 43, 'final_div_factor': 691, 'weight_decay': 1.16844641178673e-06, 'epochs': 100}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:34:57,618] Trial 25 finished with value: 3.111973122733191 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00019260177368451935, 'div_factor': 30, 'final_div_factor': 492, 'weight_decay': 0.0025996535584599705, 'epochs': 100}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:35:12,144] Trial 26 finished with value: 3.1837743789823816 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0001956199302404023, 'div_factor': 56, 'final_div_factor': 431, 'weight_decay': 0.00265346433672198, 'epochs': 200}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:35:19,772] Trial 27 finished with value: 3.161784541202223 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00014453916907943985, 'div_factor': 66, 'final_div_factor': 887, 'weight_decay': 0.0010232561327519652, 'epochs': 100}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:35:27,088] Trial 28 finished with value: 3.362407362558789 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0009624743018413565, 'div_factor': 47, 'final_div_factor': 751, 'weight_decay': 0.003264144715395315, 'epochs': 100}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:35:41,562] Trial 29 finished with value: 3.4508796399775834 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.005652117456697243, 'div_factor': 18, 'final_div_factor': 632, 'weight_decay': 0.004484068735742666, 'epochs': 200}. Best is trial 21 with value: 3.1066700273367367.
# [I 2025-09-14 11:35:48,732] Trial 30 finished with value: 3.065574037398538 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.011602490799744314, 'div_factor': 35, 'final_div_factor': 549, 'weight_decay': 0.00020702472794764584, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:35:55,830] Trial 31 finished with value: 3.3622611489248326 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.016910876779451505, 'div_factor': 35, 'final_div_factor': 548, 'weight_decay': 0.0008133386083382597, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:36:02,983] Trial 32 finished with value: 3.2450366634419585 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.010709395699942911, 'div_factor': 14, 'final_div_factor': 358, 'weight_decay': 0.00021464689090358764, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:36:10,071] Trial 33 finished with value: 3.2089995315946083 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00265250195944234, 'div_factor': 37, 'final_div_factor': 585, 'weight_decay': 0.001961781946648009, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:36:17,184] Trial 34 finished with value: 3.313771273826366 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00015963884522819582, 'div_factor': 10, 'final_div_factor': 471, 'weight_decay': 0.00036471030478461613, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:36:23,303] Trial 35 finished with value: 3.681201404710622 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0056353727431506144, 'div_factor': 55, 'final_div_factor': 637, 'weight_decay': 0.004966933185595421, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:36:31,835] Trial 36 finished with value: 4.130401542669492 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.028909534762673352, 'div_factor': 62, 'final_div_factor': 342, 'weight_decay': 8.971923512169257e-05, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:36:46,168] Trial 37 finished with value: 3.1995213031348717 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.002435476607621397, 'div_factor': 24, 'final_div_factor': 209, 'weight_decay': 0.009081941342422012, 'epochs': 200}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:36:54,187] Trial 38 finished with value: 3.503126382955096 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.009820287631608053, 'div_factor': 40, 'final_div_factor': 831, 'weight_decay': 0.001186818023814992, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:37:09,179] Trial 39 finished with value: 3.386534442748425 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0016291862838813296, 'div_factor': 67, 'final_div_factor': 738, 'weight_decay': 0.0003494532784377948, 'epochs': 200}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:37:16,217] Trial 40 finished with value: 3.9895873439094696 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.016253157662252823, 'div_factor': 82, 'final_div_factor': 534, 'weight_decay': 1.7744119823716865e-05, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:37:22,167] Trial 41 finished with value: 3.2611523530494253 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00048822661007856804, 'div_factor': 29, 'final_div_factor': 444, 'weight_decay': 1.6970103309922152e-06, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:37:28,127] Trial 42 finished with value: 3.2651734838502335 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00031402666428995954, 'div_factor': 21, 'final_div_factor': 523, 'weight_decay': 4.475639848068789e-05, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:37:34,105] Trial 43 finished with value: 3.3504524437848637 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0038242252284769484, 'div_factor': 30, 'final_div_factor': 368, 'weight_decay': 1.882216901383145e-05, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:37:40,271] Trial 44 finished with value: 3.248063170575102 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00015036835271611235, 'div_factor': 45, 'final_div_factor': 284, 'weight_decay': 5.912572184445478e-05, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:37:47,930] Trial 45 finished with value: 3.280862549204471 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0008145727551656109, 'div_factor': 33, 'final_div_factor': 452, 'weight_decay': 0.0001577536366134055, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:37:56,249] Trial 46 finished with value: 4.199484003250243 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.08833857639362654, 'div_factor': 39, 'final_div_factor': 617, 'weight_decay': 0.0019175846167154918, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:38:03,839] Trial 47 finished with value: 3.2983337357109432 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0002622417248478605, 'div_factor': 51, 'final_div_factor': 405, 'weight_decay': 0.004707327289908709, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:38:18,251] Trial 48 finished with value: 3.2960707420238693 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00011172942512143567, 'div_factor': 58, 'final_div_factor': 109, 'weight_decay': 1.2055780907271263e-05, 'epochs': 200}. Best is trial 30 with value: 3.065574037398538.
# [I 2025-09-14 11:38:25,575] Trial 49 finished with value: 3.19456894857693 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0004247444935621834, 'div_factor': 22, 'final_div_factor': 923, 'weight_decay': 1.9955585961640086e-06, 'epochs': 100}. Best is trial 30 with value: 3.065574037398538.

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 30, ValObjective: 3.0656
#
# Best Trial: 30
#   Best Score: 3.0656
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [32, 16]
#     max_lr: 0.011602490799744314
#     div_factor: 35
#     final_div_factor: 549
#     weight_decay: 0.00020702472794764584
#     epochs: 100
# Best model saved to logs/Regression/boston/CNN_hybrid/Combination/best_model/trial_30/best_model.pth
#   Seed 0: test_loss=5.006338, val_loss=10.452549, train_loss=1.679147
#
# Best Trial: 30
#   Best Score: 3.0656
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [32, 16]
#     max_lr: 0.011602490799744314
#     div_factor: 35
#     final_div_factor: 549
#     weight_decay: 0.00020702472794764584
#     epochs: 100
# Best model saved to logs/Regression/boston/CNN_hybrid/Combination/best_model/trial_30/best_model.pth
#   Seed 1: test_loss=19.252723, val_loss=11.748518, train_loss=10.421394
#
# Best Trial: 30
#   Best Score: 3.0656
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [32, 16]
#     max_lr: 0.011602490799744314
#     div_factor: 35
#     final_div_factor: 549
#     weight_decay: 0.00020702472794764584
#     epochs: 100
# Best model saved to logs/Regression/boston/CNN_hybrid/Combination/best_model/trial_30/best_model.pth
#   Seed 2: test_loss=6.373497, val_loss=13.328107, train_loss=1.009320
#
# Best Trial: 30
#   Best Score: 3.0656
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [32, 16]
#     max_lr: 0.011602490799744314
#     div_factor: 35
#     final_div_factor: 549
#     weight_decay: 0.00020702472794764584
#     epochs: 100
# Best model saved to logs/Regression/boston/CNN_hybrid/Combination/best_model/trial_30/best_model.pth
#   Seed 3: test_loss=7.667975, val_loss=11.553360, train_loss=0.802149
#
# Best Trial: 30
#   Best Score: 3.0656
#   Best Hyperparameters:
#     model: model1
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [32, 16]
#     max_lr: 0.011602490799744314
#     div_factor: 35
#     final_div_factor: 549
#     weight_decay: 0.00020702472794764584
#     epochs: 100
# Best model saved to logs/Regression/boston/CNN_hybrid/Combination/best_model/trial_30/best_model.pth
#   Seed 4: test_loss=10.734124, val_loss=11.685716, train_loss=9.122415
#   → test_loss Mean ± Std: 9.806932 ± 5.689727
# Saved to: logs/Regression/boston/CNN_hybrid/Combination/best_model/trial_30/best_results_mean.txt

# %% [markdown]
# ### EXPERIMENT: SuperTML

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"

name = f"SuperTML"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/SuperTML/train/regression.csv
# SyntheticImages/Regression/boston/SuperTML/val/regression.csv
# SyntheticImages/Regression/boston/SuperTML/test/regression.csv
# Images shape:  (3, 224, 224)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 2, 4, 7, 8, 14, 16, 28, 32, 56, 112, 224]

# %%
divisors = [16, 28, 32, 56, 112, 224]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-14 11:39:04,792] A new study created in memory with name: no-name-0039fe15-f1b0-4395-a7cc-7f7bb1a1bb20
# [I 2025-09-14 11:39:55,710] Trial 0 finished with value: 4.5570694467770645 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0327206610643215, 'div_factor': 66, 'final_div_factor': 178, 'weight_decay': 0.00099995127208892, 'epochs': 100}. Best is trial 0 with value: 4.5570694467770645.
# [I 2025-09-14 11:40:29,845] Trial 1 finished with value: 5.218189140836685 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00013375434336693445, 'div_factor': 87, 'final_div_factor': 386, 'weight_decay': 0.007869675127958815, 'epochs': 200}. Best is trial 0 with value: 4.5570694467770645.
# [I 2025-09-14 11:42:10,536] Trial 2 finished with value: 4.948986550825231 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00034477547315314884, 'div_factor': 38, 'final_div_factor': 743, 'weight_decay': 2.3496224194924422e-05, 'epochs': 200}. Best is trial 0 with value: 4.5570694467770645.
# [I 2025-09-14 11:42:28,094] Trial 3 finished with value: 3.8460770672690696 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.010925041017513631, 'div_factor': 30, 'final_div_factor': 607, 'weight_decay': 2.8097975961358488e-06, 'epochs': 100}. Best is trial 3 with value: 3.8460770672690696.
# [I 2025-09-14 11:43:06,471] Trial 4 finished with value: 3.8284362666422567 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.011829771160791322, 'div_factor': 55, 'final_div_factor': 779, 'weight_decay': 0.006270399916898646, 'epochs': 100}. Best is trial 4 with value: 3.8284362666422567.
# [I 2025-09-14 11:43:23,622] Trial 5 finished with value: 5.658729304905069 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.05266514816671388, 'div_factor': 57, 'final_div_factor': 432, 'weight_decay': 1.623997079493466e-05, 'epochs': 100}. Best is trial 4 with value: 3.8284362666422567.
# [I 2025-09-14 11:44:20,442] Trial 6 finished with value: 3.6105706682652134 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0029533668183953686, 'div_factor': 31, 'final_div_factor': 305, 'weight_decay': 0.00018240953055417364, 'epochs': 100}. Best is trial 6 with value: 3.6105706682652134.
# [I 2025-09-14 11:45:11,619] Trial 7 finished with value: 4.23912384517502 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.05498807843229217, 'div_factor': 96, 'final_div_factor': 789, 'weight_decay': 1.0599715662580734e-05, 'epochs': 100}. Best is trial 6 with value: 3.6105706682652134.
# [I 2025-09-14 11:45:45,492] Trial 8 finished with value: 3.629471881585693 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.04327527333949063, 'div_factor': 79, 'final_div_factor': 468, 'weight_decay': 0.00017034992819952587, 'epochs': 200}. Best is trial 6 with value: 3.6105706682652134.
# [I 2025-09-14 11:47:37,587] Trial 9 finished with value: 4.5325305050193165 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0001523703562618179, 'div_factor': 46, 'final_div_factor': 822, 'weight_decay': 0.0030711600059717386, 'epochs': 200}. Best is trial 6 with value: 3.6105706682652134.
# [I 2025-09-14 11:48:15,378] Trial 10 finished with value: 3.8696124864103525 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00156417178343391, 'div_factor': 11, 'final_div_factor': 152, 'weight_decay': 0.00021786904211703792, 'epochs': 100}. Best is trial 6 with value: 3.6105706682652134.
# [I 2025-09-14 11:48:59,422] Trial 11 finished with value: 3.746155230163839 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0018603554118564018, 'div_factor': 76, 'final_div_factor': 324, 'weight_decay': 0.0001784574755709205, 'epochs': 200}. Best is trial 6 with value: 3.6105706682652134.
# [I 2025-09-14 11:50:51,456] Trial 12 finished with value: 3.5538753042762665 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00824456488682099, 'div_factor': 20, 'final_div_factor': 543, 'weight_decay': 0.0006087081354439631, 'epochs': 200}. Best is trial 12 with value: 3.5538753042762665.
# [I 2025-09-14 11:52:43,313] Trial 13 finished with value: 3.429200435455163 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.005933667867617643, 'div_factor': 16, 'final_div_factor': 608, 'weight_decay': 0.0005914223805098495, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 11:54:34,990] Trial 14 finished with value: 3.5657162787533174 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.007840456734855884, 'div_factor': 11, 'final_div_factor': 987, 'weight_decay': 0.0008106811638892122, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 11:56:26,722] Trial 15 finished with value: 3.8890640007436086 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0006562520661651658, 'div_factor': 22, 'final_div_factor': 591, 'weight_decay': 0.0009871216820970712, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 11:57:42,142] Trial 16 finished with value: 3.4511340171063076 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005794595439725966, 'div_factor': 20, 'final_div_factor': 677, 'weight_decay': 6.459493052243757e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 11:58:56,486] Trial 17 finished with value: 3.7723076117964687 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.004481193315307397, 'div_factor': 44, 'final_div_factor': 673, 'weight_decay': 4.155328632969849e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:00:10,913] Trial 18 finished with value: 3.638191949110071 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.01936788021607972, 'div_factor': 22, 'final_div_factor': 922, 'weight_decay': 5.740191694438549e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:01:25,879] Trial 19 finished with value: 3.934408760683437 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0007278978824676026, 'div_factor': 36, 'final_div_factor': 678, 'weight_decay': 3.2885333354547803e-06, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:02:40,596] Trial 20 finished with value: 3.5999619905796454 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.004701342346932485, 'div_factor': 17, 'final_div_factor': 896, 'weight_decay': 6.715565624765017e-06, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:04:32,267] Trial 21 finished with value: 4.020029702527594 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.02109420768925262, 'div_factor': 25, 'final_div_factor': 523, 'weight_decay': 0.0004988598897910082, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:06:23,841] Trial 22 finished with value: 4.267144795291049 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.09791137168810161, 'div_factor': 14, 'final_div_factor': 531, 'weight_decay': 0.002896895521170633, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:08:15,397] Trial 23 finished with value: 3.6603183120138163 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.006151795107134304, 'div_factor': 21, 'final_div_factor': 602, 'weight_decay': 0.00044008900798043495, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:09:29,939] Trial 24 finished with value: 3.5216279045555807 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.002116868781645727, 'div_factor': 30, 'final_div_factor': 714, 'weight_decay': 5.7619540518990174e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:10:44,672] Trial 25 finished with value: 3.809065475594149 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.001673214607993326, 'div_factor': 30, 'final_div_factor': 689, 'weight_decay': 6.176078067319699e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:11:58,972] Trial 26 finished with value: 3.600855561423001 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0030686663528904173, 'div_factor': 45, 'final_div_factor': 859, 'weight_decay': 1.0563890484076634e-06, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:13:13,299] Trial 27 finished with value: 4.120174938302595 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0008661236833204758, 'div_factor': 38, 'final_div_factor': 722, 'weight_decay': 7.957954943712562e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:14:27,691] Trial 28 finished with value: 3.680401969600184 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.01705424593961284, 'div_factor': 27, 'final_div_factor': 667, 'weight_decay': 2.8345419548490442e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:15:41,859] Trial 29 finished with value: 3.8810394967164714 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0022170204300337236, 'div_factor': 62, 'final_div_factor': 625, 'weight_decay': 0.001622532904876388, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:16:56,193] Trial 30 finished with value: 3.7816172019533356 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0009767279812452603, 'div_factor': 10, 'final_div_factor': 497, 'weight_decay': 0.0003374704295396402, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:18:47,865] Trial 31 finished with value: 3.4705980206634006 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.007168583650325513, 'div_factor': 17, 'final_div_factor': 426, 'weight_decay': 0.000127492387031067, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:20:39,161] Trial 32 finished with value: 3.642608626087112 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00457137199935492, 'div_factor': 17, 'final_div_factor': 364, 'weight_decay': 0.00012464731615645724, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:22:30,798] Trial 33 finished with value: 3.6395770353289336 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.013588871645336013, 'div_factor': 17, 'final_div_factor': 229, 'weight_decay': 8.525626241647784e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:24:11,688] Trial 34 finished with value: 3.7695235336303794 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.006904017312322969, 'div_factor': 35, 'final_div_factor': 413, 'weight_decay': 3.3432534551908876e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:24:56,952] Trial 35 finished with value: 3.8707776599790855 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.001247543683674934, 'div_factor': 27, 'final_div_factor': 758, 'weight_decay': 0.00026935122895760296, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:25:29,655] Trial 36 finished with value: 5.165144214075466 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00048605366048874976, 'div_factor': 33, 'final_div_factor': 469, 'weight_decay': 1.796495469039808e-05, 'epochs': 100}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:27:23,015] Trial 37 finished with value: 3.904264754315408 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.028954355363946173, 'div_factor': 50, 'final_div_factor': 636, 'weight_decay': 0.00011144109582972615, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:27:40,291] Trial 38 finished with value: 4.113567577804343 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0024844005770065652, 'div_factor': 40, 'final_div_factor': 238, 'weight_decay': 4.9280603153101455e-05, 'epochs': 100}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:28:54,543] Trial 39 finished with value: 3.457021042975751 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.004148209170159736, 'div_factor': 25, 'final_div_factor': 581, 'weight_decay': 1.1058918753396712e-05, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:29:45,764] Trial 40 finished with value: 3.6059285673491517 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.011958698347846563, 'div_factor': 14, 'final_div_factor': 575, 'weight_decay': 1.0836032075695166e-05, 'epochs': 100}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:31:00,391] Trial 41 finished with value: 3.458517291833331 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.003833456581156136, 'div_factor': 25, 'final_div_factor': 735, 'weight_decay': 5.963301528036004e-06, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:32:15,105] Trial 42 finished with value: 3.695694304857816 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0035518305478601272, 'div_factor': 25, 'final_div_factor': 800, 'weight_decay': 5.206513730308223e-06, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:33:31,038] Trial 43 finished with value: 3.4898233966904244 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.009754849652406172, 'div_factor': 16, 'final_div_factor': 458, 'weight_decay': 1.4048104030841574e-06, 'epochs': 200}. Best is trial 13 with value: 3.429200435455163.
# [I 2025-09-14 12:34:46,803] Trial 44 finished with value: 3.344401643661535 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005626285407491036, 'div_factor': 99, 'final_div_factor': 375, 'weight_decay': 1.0875623097851136e-05, 'epochs': 200}. Best is trial 44 with value: 3.344401643661535.
# [I 2025-09-14 12:36:02,923] Trial 45 finished with value: 3.617520211986501 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005475376068333218, 'div_factor': 94, 'final_div_factor': 748, 'weight_decay': 9.081986167522433e-06, 'epochs': 200}. Best is trial 44 with value: 3.344401643661535.
# [I 2025-09-14 12:37:19,124] Trial 46 finished with value: 3.662653345015992 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0034800434463766816, 'div_factor': 74, 'final_div_factor': 564, 'weight_decay': 2.9842189444919706e-06, 'epochs': 200}. Best is trial 44 with value: 3.344401643661535.
# [I 2025-09-14 12:37:57,593] Trial 47 finished with value: 3.8245132535509554 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0038543635067924166, 'div_factor': 86, 'final_div_factor': 634, 'weight_decay': 1.6790525812445204e-05, 'epochs': 100}. Best is trial 44 with value: 3.344401643661535.
# [I 2025-09-14 12:39:13,689] Trial 48 finished with value: 3.5254443220027607 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.010184733944842126, 'div_factor': 100, 'final_div_factor': 364, 'weight_decay': 6.071122708109328e-06, 'epochs': 200}. Best is trial 44 with value: 3.344401643661535.
# [I 2025-09-14 12:39:47,908] Trial 49 finished with value: 4.60988083989513 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0028018907267311722, 'div_factor': 64, 'final_div_factor': 827, 'weight_decay': 1.7432437145328585e-06, 'epochs': 200}. Best is trial 44 with value: 3.344401643661535.

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 44, ValObjective: 3.3444
#
# Best Trial: 44
#   Best Score: 3.3444
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [256, 128, 64]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.005626285407491036
#     div_factor: 99
#     final_div_factor: 375
#     weight_decay: 1.0875623097851136e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/SuperTML/best_model/trial_44/best_model.pth
#   Seed 0: test_loss=13.792780, val_loss=13.493293, train_loss=1.380149
#
# Best Trial: 44
#   Best Score: 3.3444
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [256, 128, 64]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.005626285407491036
#     div_factor: 99
#     final_div_factor: 375
#     weight_decay: 1.0875623097851136e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/SuperTML/best_model/trial_44/best_model.pth
#   Seed 1: test_loss=10.327184, val_loss=12.035148, train_loss=3.422039
#
# Best Trial: 44
#   Best Score: 3.3444
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [256, 128, 64]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.005626285407491036
#     div_factor: 99
#     final_div_factor: 375
#     weight_decay: 1.0875623097851136e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/SuperTML/best_model/trial_44/best_model.pth
#   Seed 2: test_loss=15.451991, val_loss=14.493648, train_loss=2.972905
#
# Best Trial: 44
#   Best Score: 3.3444
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [256, 128, 64]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.005626285407491036
#     div_factor: 99
#     final_div_factor: 375
#     weight_decay: 1.0875623097851136e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/SuperTML/best_model/trial_44/best_model.pth
#   Seed 3: test_loss=10.096553, val_loss=13.600004, train_loss=1.991886
#
# Best Trial: 44
#   Best Score: 3.3444
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [256, 128, 64]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.005626285407491036
#     div_factor: 99
#     final_div_factor: 375
#     weight_decay: 1.0875623097851136e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/SuperTML/best_model/trial_44/best_model.pth
#   Seed 4: test_loss=6.933991, val_loss=13.919821, train_loss=2.585602
#   → test_loss Mean ± Std: 11.320500 ± 3.350656
# Saved to: logs/Regression/boston/CNN_hybrid/SuperTML/best_model/trial_44/best_results_mean.txt

# %% [markdown]
# ### EXPERIMENT: FeatureWrap

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"

name = f"FeatureWrap"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/FeatureWrap/train/regression.csv
# SyntheticImages/Regression/boston/FeatureWrap/val/regression.csv
# SyntheticImages/Regression/boston/FeatureWrap/test/regression.csv
# Images shape:  (3, 8, 8)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 2, 4, 8]

# %%
divisors = [2, 4, 8]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-14 12:46:32,520] A new study created in memory with name: no-name-1cc09252-3c93-4ada-9c46-45f3022eaf44
# [I 2025-09-14 12:46:41,734] Trial 0 finished with value: 3.988215491698955 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.009989641949744405, 'div_factor': 28, 'final_div_factor': 152, 'weight_decay': 1.4949469496120247e-06, 'epochs': 100}. Best is trial 0 with value: 3.988215491698955.
# [I 2025-09-14 12:47:03,944] Trial 1 finished with value: 4.721181281056536 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.08429556942019817, 'div_factor': 36, 'final_div_factor': 258, 'weight_decay': 5.783961555323382e-06, 'epochs': 200}. Best is trial 0 with value: 3.988215491698955.
# [I 2025-09-14 12:47:14,019] Trial 2 finished with value: 5.050426261210223 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0006782840835707302, 'div_factor': 80, 'final_div_factor': 579, 'weight_decay': 2.468099179750013e-05, 'epochs': 100}. Best is trial 0 with value: 3.988215491698955.
# [I 2025-09-14 12:47:31,196] Trial 3 finished with value: 3.357585341561209 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.013523084628131982, 'div_factor': 20, 'final_div_factor': 417, 'weight_decay': 5.318914205650778e-05, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:47:54,680] Trial 4 finished with value: 3.385238376715516 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00047938068856280726, 'div_factor': 74, 'final_div_factor': 903, 'weight_decay': 1.8374407530778327e-06, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:48:06,444] Trial 5 finished with value: 3.8903841610557257 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.023273094023857188, 'div_factor': 69, 'final_div_factor': 199, 'weight_decay': 1.760386580508747e-06, 'epochs': 100}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:48:25,974] Trial 6 finished with value: 3.7636642733122505 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.03329099664515486, 'div_factor': 67, 'final_div_factor': 401, 'weight_decay': 1.1352932871867458e-06, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:48:43,700] Trial 7 finished with value: 3.634561884528624 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.08439776731645912, 'div_factor': 19, 'final_div_factor': 146, 'weight_decay': 3.883926441840139e-05, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:49:02,131] Trial 8 finished with value: 3.6858593151796213 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.005014389573356369, 'div_factor': 90, 'final_div_factor': 189, 'weight_decay': 9.35986639657352e-05, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:49:19,198] Trial 9 finished with value: 4.043577522479055 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0010050912691765535, 'div_factor': 51, 'final_div_factor': 426, 'weight_decay': 0.00021725301291044107, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:49:28,211] Trial 10 finished with value: 4.709281668342541 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00010665619478316643, 'div_factor': 44, 'final_div_factor': 664, 'weight_decay': 0.002458975257477391, 'epochs': 100}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:49:51,585] Trial 11 finished with value: 3.7301101911698322 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0010057896873018764, 'div_factor': 10, 'final_div_factor': 961, 'weight_decay': 0.0006665652756652438, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:50:14,942] Trial 12 finished with value: 3.4396207336450337 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00011862172721066671, 'div_factor': 98, 'final_div_factor': 907, 'weight_decay': 1.1007099333198232e-05, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:50:36,033] Trial 13 finished with value: 3.7949145872131513 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.00039225034221261075, 'div_factor': 63, 'final_div_factor': 716, 'weight_decay': 0.005883996912332376, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:50:56,283] Trial 14 finished with value: 3.4443499200081225 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.003048957086610598, 'div_factor': 83, 'final_div_factor': 782, 'weight_decay': 0.0004702934088785863, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:51:09,523] Trial 15 finished with value: 3.4454066118807236 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.002675282412389941, 'div_factor': 55, 'final_div_factor': 392, 'weight_decay': 6.649019325851437e-06, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:51:25,160] Trial 16 finished with value: 3.730990867626063 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.009900434060676115, 'div_factor': 34, 'final_div_factor': 844, 'weight_decay': 4.887705521952448e-05, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:51:41,845] Trial 17 finished with value: 3.693451943288995 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0003151097294922897, 'div_factor': 75, 'final_div_factor': 536, 'weight_decay': 3.804784412256728e-06, 'epochs': 200}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:51:48,718] Trial 18 finished with value: 3.572311943342075 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0017528301299346454, 'div_factor': 43, 'final_div_factor': 524, 'weight_decay': 1.645262570035191e-05, 'epochs': 100}. Best is trial 3 with value: 3.357585341561209.
# [I 2025-09-14 12:52:05,473] Trial 19 finished with value: 3.2911970230051986 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.01084784070491123, 'div_factor': 59, 'final_div_factor': 298, 'weight_decay': 0.00013905700282647906, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:52:22,158] Trial 20 finished with value: 3.807914978576836 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.022272541424520585, 'div_factor': 57, 'final_div_factor': 308, 'weight_decay': 0.0001422081672590732, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:52:38,645] Trial 21 finished with value: 3.4022014951694013 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.007930772142194011, 'div_factor': 74, 'final_div_factor': 296, 'weight_decay': 0.0007577032246935224, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:52:55,197] Trial 22 finished with value: 3.4622559113659657 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.014614637722833737, 'div_factor': 62, 'final_div_factor': 462, 'weight_decay': 6.762481619823275e-05, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:53:11,949] Trial 23 finished with value: 4.0447132124927565 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.04265536016491558, 'div_factor': 49, 'final_div_factor': 619, 'weight_decay': 0.00022670828190532192, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:53:28,773] Trial 24 finished with value: 3.3277650737006943 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.004929527299400287, 'div_factor': 89, 'final_div_factor': 325, 'weight_decay': 2.782558224320777e-06, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:53:45,514] Trial 25 finished with value: 3.445988941177096 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.005407314711645511, 'div_factor': 99, 'final_div_factor': 355, 'weight_decay': 0.0024429756310836042, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:53:58,980] Trial 26 finished with value: 3.551772177632828 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.004877505687762059, 'div_factor': 19, 'final_div_factor': 474, 'weight_decay': 2.860125513857104e-05, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:54:07,399] Trial 27 finished with value: 3.5445787163882203 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.01614623124418736, 'div_factor': 88, 'final_div_factor': 248, 'weight_decay': 0.0002648764706461917, 'epochs': 100}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:54:20,933] Trial 28 finished with value: 3.6839954080377018 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.044527321028947284, 'div_factor': 25, 'final_div_factor': 347, 'weight_decay': 1.3395150216008031e-05, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:54:28,635] Trial 29 finished with value: 3.9860111243231042 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00861964055728501, 'div_factor': 10, 'final_div_factor': 127, 'weight_decay': 3.0472908462653962e-06, 'epochs': 100}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:54:45,210] Trial 30 finished with value: 3.4113436070532828 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0019461283710046956, 'div_factor': 36, 'final_div_factor': 485, 'weight_decay': 0.001302840198255392, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:55:01,868] Trial 31 finished with value: 3.9943331870223036 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.015240685211018845, 'div_factor': 91, 'final_div_factor': 332, 'weight_decay': 2.455147917804941e-06, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:55:18,663] Trial 32 finished with value: 3.345623881687068 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.005630738326674598, 'div_factor': 77, 'final_div_factor': 243, 'weight_decay': 5.169230739042926e-06, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:55:35,510] Trial 33 finished with value: 3.4504701929754886 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.00644977952165462, 'div_factor': 83, 'final_div_factor': 240, 'weight_decay': 6.244978975025432e-06, 'epochs': 200}. Best is trial 19 with value: 3.2911970230051986.
# [I 2025-09-14 12:55:52,379] Trial 34 finished with value: 3.2844982236618416 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0037920105290655945, 'div_factor': 78, 'final_div_factor': 104, 'weight_decay': 8.70205132875921e-06, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:56:09,145] Trial 35 finished with value: 3.311105110566962 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.003965921724545482, 'div_factor': 77, 'final_div_factor': 117, 'weight_decay': 9.094661532604544e-06, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:56:17,681] Trial 36 finished with value: 3.356020792090806 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0035726382364085953, 'div_factor': 68, 'final_div_factor': 105, 'weight_decay': 1.2969428639613945e-05, 'epochs': 100}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:56:34,565] Trial 37 finished with value: 3.536097482390476 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0015847103008115153, 'div_factor': 94, 'final_div_factor': 182, 'weight_decay': 2.5871573908522295e-05, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:56:51,054] Trial 38 finished with value: 3.7192704293382985 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.002530247107004623, 'div_factor': 81, 'final_div_factor': 174, 'weight_decay': 1.0903700745169506e-06, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:57:07,887] Trial 39 finished with value: 3.3408261644478854 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.003653540095631638, 'div_factor': 86, 'final_div_factor': 211, 'weight_decay': 9.113320370087015e-06, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:57:16,257] Trial 40 finished with value: 3.700398660782141 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0013185329380155195, 'div_factor': 71, 'final_div_factor': 111, 'weight_decay': 2.0014007974382e-06, 'epochs': 100}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:57:33,230] Trial 41 finished with value: 3.4277456430103252 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0043432248689781044, 'div_factor': 87, 'final_div_factor': 210, 'weight_decay': 7.828355404410885e-06, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:57:50,055] Trial 42 finished with value: 3.5135311418713657 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0036164523023986574, 'div_factor': 85, 'final_div_factor': 156, 'weight_decay': 3.7819232439196324e-06, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:58:06,931] Trial 43 finished with value: 3.5041081977408473 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.007365824893716335, 'div_factor': 79, 'final_div_factor': 289, 'weight_decay': 2.1860644181118615e-05, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:58:23,760] Trial 44 finished with value: 3.527406204025593 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.011265994934503549, 'div_factor': 95, 'final_div_factor': 228, 'weight_decay': 0.0001376859605996464, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:58:40,561] Trial 45 finished with value: 3.604202990633695 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.02329588832954037, 'div_factor': 92, 'final_div_factor': 143, 'weight_decay': 7.994425223190042e-06, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:58:57,439] Trial 46 finished with value: 3.6680293296548228 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0009740643803635255, 'div_factor': 64, 'final_div_factor': 209, 'weight_decay': 1.6144200426527569e-06, 'epochs': 200}. Best is trial 34 with value: 3.2844982236618416.
# [I 2025-09-14 12:59:13,971] Trial 47 finished with value: 3.2669213747126955 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.002215302390270786, 'div_factor': 70, 'final_div_factor': 275, 'weight_decay': 7.875018674141369e-05, 'epochs': 200}. Best is trial 47 with value: 3.2669213747126955.
# [I 2025-09-14 12:59:30,451] Trial 48 finished with value: 3.2899051411412334 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0023488363703498094, 'div_factor': 70, 'final_div_factor': 273, 'weight_decay': 7.88080674396274e-05, 'epochs': 200}. Best is trial 47 with value: 3.2669213747126955.
# [I 2025-09-14 12:59:48,496] Trial 49 finished with value: 3.945682802857031 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.0020248461652095503, 'div_factor': 71, 'final_div_factor': 277, 'weight_decay': 9.048546559562702e-05, 'epochs': 200}. Best is trial 47 with value: 3.2669213747126955.

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 47, ValObjective: 3.2669
#
# Best Trial: 47
#   Best Score: 3.2669
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.002215302390270786
#     div_factor: 70
#     final_div_factor: 275
#     weight_decay: 7.875018674141369e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/FeatureWrap/best_model/trial_47/best_model.pth
#   Seed 0: test_loss=13.219134, val_loss=13.527248, train_loss=8.586879
#
# Best Trial: 47
#   Best Score: 3.2669
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.002215302390270786
#     div_factor: 70
#     final_div_factor: 275
#     weight_decay: 7.875018674141369e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/FeatureWrap/best_model/trial_47/best_model.pth
#   Seed 1: test_loss=8.632610, val_loss=13.324207, train_loss=5.177723
#
# Best Trial: 47
#   Best Score: 3.2669
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.002215302390270786
#     div_factor: 70
#     final_div_factor: 275
#     weight_decay: 7.875018674141369e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/FeatureWrap/best_model/trial_47/best_model.pth
#   Seed 2: test_loss=12.677882, val_loss=12.488136, train_loss=6.960845
#
# Best Trial: 47
#   Best Score: 3.2669
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.002215302390270786
#     div_factor: 70
#     final_div_factor: 275
#     weight_decay: 7.875018674141369e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/FeatureWrap/best_model/trial_47/best_model.pth
#   Seed 3: test_loss=9.445299, val_loss=14.989085, train_loss=3.210644
#
# Best Trial: 47
#   Best Score: 3.2669
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [32, 16]
#     fusion_hidden_dims: [128, 64, 32]
#     max_lr: 0.002215302390270786
#     div_factor: 70
#     final_div_factor: 275
#     weight_decay: 7.875018674141369e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/FeatureWrap/best_model/trial_47/best_model.pth
#   Seed 4: test_loss=11.751061, val_loss=13.125754, train_loss=5.339135
#   → test_loss Mean ± Std: 11.145197 ± 2.013713
# Saved to: logs/Regression/boston/CNN_hybrid/FeatureWrap/best_model/trial_47/best_results_mean.txt

# %% [markdown]
# ### EXPERIMENT: BIE

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"

name = f"BIE"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)
# Out:
# Shapes — Train: (354, 22), Val: (76, 22), Test: (76, 22)
# Numerical features: 11 — ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT']
# Categorical features: 2 — ['CHAS', 'RAD']
# Total features: 22
# SyntheticImages/Regression/boston/BIE/train/regression.csv
# SyntheticImages/Regression/boston/BIE/val/regression.csv
# SyntheticImages/Regression/boston/BIE/test/regression.csv
# Images shape:  (3, 64, 64)
# Attributes:  22

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors = find_divisors(imgs_shape[1])
divisors
# Out:
# [1, 2, 4, 8, 16, 32, 64]

# %%
divisors = [4, 8, 16, 32]

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors=divisors,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)
# Out:
# [I 2025-09-16 12:11:30,251] A new study created in memory with name: no-name-e213b718-e761-4eb3-b470-f119734c4ca9
# [I 2025-09-16 12:11:48,409] Trial 0 finished with value: 6.225936034886485 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0007341902290139219, 'div_factor': 34, 'final_div_factor': 947, 'weight_decay': 1.8270777248437804e-05, 'epochs': 200}. Best is trial 0 with value: 6.225936034886485.
# [I 2025-09-16 12:12:08,629] Trial 1 finished with value: 6.081440391578965 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.005576498489807954, 'div_factor': 79, 'final_div_factor': 814, 'weight_decay': 1.024235003186395e-05, 'epochs': 200}. Best is trial 1 with value: 6.081440391578965.
# [I 2025-09-16 12:12:16,344] Trial 2 finished with value: 6.196664823737374 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.058581531777653344, 'div_factor': 98, 'final_div_factor': 300, 'weight_decay': 2.1701749033176522e-05, 'epochs': 100}. Best is trial 1 with value: 6.081440391578965.
# [I 2025-09-16 12:12:26,698] Trial 3 finished with value: 5.338431941199617 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.03490743097805796, 'div_factor': 96, 'final_div_factor': 640, 'weight_decay': 3.597207554880025e-05, 'epochs': 100}. Best is trial 3 with value: 5.338431941199617.
# [I 2025-09-16 12:12:39,240] Trial 4 finished with value: 4.9347383526021495 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.025810187492034963, 'div_factor': 54, 'final_div_factor': 156, 'weight_decay': 0.004914766845138485, 'epochs': 100}. Best is trial 4 with value: 4.9347383526021495.
# [I 2025-09-16 12:13:03,557] Trial 5 finished with value: 3.5529436130574767 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.014517338103116808, 'div_factor': 93, 'final_div_factor': 922, 'weight_decay': 4.836783766043952e-05, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:13:24,221] Trial 6 finished with value: 5.702276799082922 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.011672736990487, 'div_factor': 78, 'final_div_factor': 840, 'weight_decay': 8.042565450388067e-05, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:13:34,794] Trial 7 finished with value: 5.596701243060696 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.000186892492509138, 'div_factor': 96, 'final_div_factor': 875, 'weight_decay': 0.00010126584482829475, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:13:44,032] Trial 8 finished with value: 4.647651259662811 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.07820504083271336, 'div_factor': 36, 'final_div_factor': 891, 'weight_decay': 0.00022374467327175102, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:13:53,090] Trial 9 finished with value: 5.839583763025463 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.00014080856210201258, 'div_factor': 71, 'final_div_factor': 495, 'weight_decay': 2.020208869993198e-06, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:14:16,959] Trial 10 finished with value: 5.283965546881884 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0011518246208404611, 'div_factor': 11, 'final_div_factor': 570, 'weight_decay': 0.0025299745600739737, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:14:36,378] Trial 11 finished with value: 3.920462426138736 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.09390435534209193, 'div_factor': 36, 'final_div_factor': 714, 'weight_decay': 0.00040244396831767533, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:14:56,028] Trial 12 finished with value: 3.7568122024123505 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.013433725573651042, 'div_factor': 47, 'final_div_factor': 705, 'weight_decay': 0.0006857409147863096, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:15:20,692] Trial 13 finished with value: 3.9412113440178937 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.009351819812839357, 'div_factor': 52, 'final_div_factor': 712, 'weight_decay': 0.0007687906714084955, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:15:39,465] Trial 14 finished with value: 4.568986644956625 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.002528748082534662, 'div_factor': 64, 'final_div_factor': 985, 'weight_decay': 0.0009029287646709177, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:15:58,691] Trial 15 finished with value: 3.787976044302159 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.015964407555894025, 'div_factor': 22, 'final_div_factor': 472, 'weight_decay': 3.4176118407883703e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:16:21,863] Trial 16 finished with value: 4.560859280654215 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.003933314673982025, 'div_factor': 45, 'final_div_factor': 740, 'weight_decay': 0.001896441813180836, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:16:44,852] Trial 17 finished with value: 5.288136523736576 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0016184267220591083, 'div_factor': 64, 'final_div_factor': 395, 'weight_decay': 0.009511282533830438, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:17:00,923] Trial 18 finished with value: 5.552138547163554 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.006713903833139696, 'div_factor': 86, 'final_div_factor': 621, 'weight_decay': 0.00016754416787167876, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:17:22,247] Trial 19 finished with value: 4.50546081658689 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.026166653368615532, 'div_factor': 45, 'final_div_factor': 790, 'weight_decay': 5.574060514412169e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:17:45,298] Trial 20 finished with value: 3.6426573225723473 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.013243654320939968, 'div_factor': 64, 'final_div_factor': 987, 'weight_decay': 1.0766345136045805e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:18:08,561] Trial 21 finished with value: 4.002103252583064 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.015724796571404652, 'div_factor': 63, 'final_div_factor': 999, 'weight_decay': 1.1968396763163118e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:18:31,878] Trial 22 finished with value: 4.09789456528155 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.040092548132721506, 'div_factor': 86, 'final_div_factor': 889, 'weight_decay': 5.052404425115572e-05, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:18:55,433] Trial 23 finished with value: 4.222793562753549 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.017455389323814, 'div_factor': 24, 'final_div_factor': 946, 'weight_decay': 0.0007536418572407625, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:19:18,476] Trial 24 finished with value: 4.231951142993569 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.005895144067321351, 'div_factor': 46, 'final_div_factor': 767, 'weight_decay': 6.969886855744527e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:19:37,482] Trial 25 finished with value: 4.651258007228226 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.003463170581229165, 'div_factor': 71, 'final_div_factor': 632, 'weight_decay': 0.0003181788051500672, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:20:00,884] Trial 26 finished with value: 4.122942787204607 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.010422227630183026, 'div_factor': 58, 'final_div_factor': 918, 'weight_decay': 0.001518239011733883, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:20:21,727] Trial 27 finished with value: 5.833868964898798 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.0004863400158647365, 'div_factor': 88, 'final_div_factor': 852, 'weight_decay': 1.3059660414529003e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:20:40,864] Trial 28 finished with value: 4.621665371054243 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.04003811356995578, 'div_factor': 73, 'final_div_factor': 689, 'weight_decay': 0.00011704964352509353, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:21:02,289] Trial 29 finished with value: 3.8907279495038947 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.020483726880362756, 'div_factor': 24, 'final_div_factor': 940, 'weight_decay': 1.337828420009211e-05, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:21:20,498] Trial 30 finished with value: 4.935857378873015 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.0022834264875377513, 'div_factor': 30, 'final_div_factor': 996, 'weight_decay': 3.20219658538244e-05, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:21:39,589] Trial 31 finished with value: 3.9682171080860407 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.013659317144367212, 'div_factor': 10, 'final_div_factor': 458, 'weight_decay': 3.178478074494832e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:21:58,674] Trial 32 finished with value: 3.983296446582888 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.007551171706849976, 'div_factor': 17, 'final_div_factor': 377, 'weight_decay': 2.8948481922433828e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:22:17,712] Trial 33 finished with value: 4.004113704610328 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.004557759365889409, 'div_factor': 38, 'final_div_factor': 231, 'weight_decay': 5.321840816793829e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:22:33,916] Trial 34 finished with value: 4.795880043648549 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.02494997930601408, 'div_factor': 23, 'final_div_factor': 531, 'weight_decay': 2.0881590070260823e-05, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:22:43,600] Trial 35 finished with value: 4.229533112283245 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.052353622244172865, 'div_factor': 41, 'final_div_factor': 377, 'weight_decay': 9.898474527156414e-06, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:23:06,791] Trial 36 finished with value: 3.879324561052838 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.009292710756667549, 'div_factor': 30, 'final_div_factor': 812, 'weight_decay': 1.637144464313776e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:23:14,781] Trial 37 finished with value: 6.108274082592104 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.014370628303135057, 'div_factor': 100, 'final_div_factor': 309, 'weight_decay': 2.756180158614719e-06, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:23:35,379] Trial 38 finished with value: 4.720496050420563 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.059359647134709675, 'div_factor': 80, 'final_div_factor': 453, 'weight_decay': 1.0106736761509105e-06, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:23:47,175] Trial 39 finished with value: 3.6601609399983293 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.027914761234483967, 'div_factor': 90, 'final_div_factor': 576, 'weight_decay': 5.772744346308497e-05, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:23:57,697] Trial 40 finished with value: 6.163289803735825 and parameters: {'model': 'model1', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.030102775832150194, 'div_factor': 90, 'final_div_factor': 674, 'weight_decay': 5.9269273120399084e-05, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:24:09,613] Trial 41 finished with value: 4.081680092925148 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.023158133520587546, 'div_factor': 91, 'final_div_factor': 554, 'weight_decay': 3.0223135038083985e-05, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:24:21,290] Trial 42 finished with value: 4.38952123268833 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.012075730669666784, 'div_factor': 80, 'final_div_factor': 608, 'weight_decay': 1.3082856940396938e-05, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:24:33,164] Trial 43 finished with value: 4.284538620955354 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.04689906591614155, 'div_factor': 51, 'final_div_factor': 508, 'weight_decay': 0.00014686578138400444, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:24:44,572] Trial 44 finished with value: 5.902894696841708 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[32, 16]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.03352545241811772, 'div_factor': 93, 'final_div_factor': 452, 'weight_decay': 6.979052645404916e-05, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:24:56,318] Trial 45 finished with value: 4.747624254895687 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.017986679967158612, 'div_factor': 82, 'final_div_factor': 580, 'weight_decay': 0.00044676016825595885, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:25:14,868] Trial 46 finished with value: 4.543058806139322 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[32, 16]', 'max_lr': 0.06935717437799109, 'div_factor': 75, 'final_div_factor': 834, 'weight_decay': 0.00023729685246475448, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:25:25,627] Trial 47 finished with value: 4.2553289327103165 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[128, 64, 32]', 'fusion_hidden_dims': '[128, 64, 32]', 'max_lr': 0.008273460242071304, 'div_factor': 58, 'final_div_factor': 667, 'weight_decay': 0.004095256268879942, 'epochs': 100}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:25:48,885] Trial 48 finished with value: 3.72078681110775 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.012051983896711516, 'div_factor': 69, 'final_div_factor': 753, 'weight_decay': 8.560634396138838e-05, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.
# [I 2025-09-16 12:26:12,261] Trial 49 finished with value: 3.969523557232447 and parameters: {'model': 'model2', 'mlp_hidden_dims': '[256, 128, 64]', 'fusion_hidden_dims': '[256, 128, 64]', 'max_lr': 0.004986648496382589, 'div_factor': 96, 'final_div_factor': 744, 'weight_decay': 8.608351905749754e-05, 'epochs': 200}. Best is trial 5 with value: 3.5529436130574767.

# %%
from numbers import Number

# --- Configure which seeds to use for stability reporting ---
model_seeds = [0, 1, 2, 3, 4]   # change as needed
numeric_keys = None  # we’ll infer from first run

# Determine study direction safely (minimize by default if unknown)
def is_minimize_study(study):
    try:
        return study.direction == optuna.study.StudyDirection.MINIMIZE
    except Exception:
        try:
            return study.directions[0] == optuna.study.StudyDirection.MINIMIZE
        except Exception:
            return True  # fallback

minimize = is_minimize_study(study)

# --- Pick the single best completed trial across ALL patch sizes ---
completed = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
if not completed:
    raise RuntimeError("No completed trials in the study.")

best_trial = (min if minimize else max)(completed, key=lambda t: t.value)

if model_name == "ViT_hybrid":
    # Extract its patch_size (may be None if not used in search)
    best_patch = best_trial.params.get("patch_size", None)
    trial_name = f"trial_{best_trial.number}_patch{best_patch}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}, "
      f"patch_size={best_patch})")
else:
    trial_name = f"trial_{best_trial.number}"
    print(f"\nEvaluating overall best trial "
      f"(Trial {best_trial.number}, ValObjective: {best_trial.value:.4f}")
    
save_path = os.path.join(save_dir, f"{model_name}/{name}/best_model/{trial_name}")
os.makedirs(save_path, exist_ok=True)

per_seed_metrics = []

for s in model_seeds:
    set_model_seed(s)
    metrics = evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,          # keep your original arg
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=num_classes,
        epochs=epochs,
        trial_name=trial_name
        # If evaluate_best_model accepts a seed arg, pass model_seed=s
    )
    if not isinstance(metrics, dict):
        raise TypeError(f"evaluate_best_model must return dict, got: {type(metrics)}")

    # infer numeric keys once (ints, floats, numpy scalars)
    if numeric_keys is None:
        numeric_keys = [k for k, v in metrics.items()
                        if isinstance(v, (Number, np.floating, np.integer))]
    per_seed_metrics.append(metrics)

    # brief per-seed printout
    log_bits = []
    for k in ["test_loss", "val_loss", "train_loss"]:
        if k in metrics and isinstance(metrics[k], (Number, np.floating, np.integer)):
            log_bits.append(f"{k}={float(metrics[k]):.6f}")
    print(f"  Seed {s}: " + (", ".join(log_bits) if log_bits else str(metrics)))

# Aggregate mean/std per numeric key
aggregates = {}
for k in numeric_keys:
    vals = [float(m[k]) for m in per_seed_metrics]
    mean_k = float(np.mean(vals))
    std_k = float(np.std(vals, ddof=1)) if len(vals) > 1 else 0.0
    aggregates[k] = {"mean": mean_k, "std": std_k}

# Save YAML-like txt
out_file = os.path.join(save_path, "best_results_mean.txt")
with open(out_file, "w", encoding="utf-8") as f:
    f.write("# Overall best trial re-evaluation across model seeds\n")
    f.write(f"trial_number: {best_trial.number}\n")
    if model_name == "ViT_with_register_tokens":
        f.write(f"patch_size: {best_patch}\n")
    f.write(f"val_objective_best: {best_trial.value:.6f}\n")
    f.write(f"direction: {'minimize' if minimize else 'maximize'}\n")
    f.write(f"seeds: {model_seeds}\n")
    f.write("per_seed_metrics:\n")
    for s, m in zip(model_seeds, per_seed_metrics):
        f.write(f"  - seed: {s}\n")
        for k in numeric_keys:
            f.write(f"      {k}: {float(m[k]):.6f}\n")
    f.write("aggregates:\n")
    for k, mm in aggregates.items():
        f.write(f"  {k}:\n")
        f.write(f"    mean: {mm['mean']:.6f}\n")
        f.write(f"    std: {mm['std']:.6f}\n")

# Console summary
if "test_loss" in aggregates:
    print("  → test_loss Mean ± Std: "
          f"{aggregates['test_loss']['mean']:.6f} ± {aggregates['test_loss']['std']:.6f}")
elif "val_loss" in aggregates:
    print("  → val_loss Mean ± Std: "
          f"{aggregates['val_loss']['mean']:.6f} ± {aggregates['val_loss']['std']:.6f}")

print(f"Saved to: {out_file}")
# Out:
# Evaluating overall best trial (Trial 5, ValObjective: 3.5529
#
# Best Trial: 5
#   Best Score: 3.5529
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.014517338103116808
#     div_factor: 93
#     final_div_factor: 922
#     weight_decay: 4.836783766043952e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BIE/best_model/trial_5/best_model.pth
#   Seed 0: test_loss=11.021610, val_loss=15.015516, train_loss=6.778717
#
# Best Trial: 5
#   Best Score: 3.5529
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.014517338103116808
#     div_factor: 93
#     final_div_factor: 922
#     weight_decay: 4.836783766043952e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BIE/best_model/trial_5/best_model.pth
#   Seed 1: test_loss=16.616910, val_loss=14.426194, train_loss=2.750998
#
# Best Trial: 5
#   Best Score: 3.5529
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.014517338103116808
#     div_factor: 93
#     final_div_factor: 922
#     weight_decay: 4.836783766043952e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BIE/best_model/trial_5/best_model.pth
#   Seed 2: test_loss=14.100654, val_loss=17.037890, train_loss=1.663237
#
# Best Trial: 5
#   Best Score: 3.5529
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.014517338103116808
#     div_factor: 93
#     final_div_factor: 922
#     weight_decay: 4.836783766043952e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BIE/best_model/trial_5/best_model.pth
#   Seed 3: test_loss=13.884030, val_loss=17.192564, train_loss=9.789467
#
# Best Trial: 5
#   Best Score: 3.5529
#   Best Hyperparameters:
#     model: model2
#     mlp_hidden_dims: [128, 64, 32]
#     fusion_hidden_dims: [256, 128, 64]
#     max_lr: 0.014517338103116808
#     div_factor: 93
#     final_div_factor: 922
#     weight_decay: 4.836783766043952e-05
#     epochs: 200
# Best model saved to logs/Regression/boston/CNN_hybrid/BIE/best_model/trial_5/best_model.pth
#   Seed 4: test_loss=12.755384, val_loss=14.852659, train_loss=0.796436
#   → test_loss Mean ± Std: 13.675717 ± 2.047308
# Saved to: logs/Regression/boston/CNN_hybrid/BIE/best_model/trial_5/best_results_mean.txt

# %% [markdown]
# ### EXPERIMENT: MANUEL

# %%
#Select the model and the parameters
if task_type.lower() == "regression":
    problem_type = "regression"
else:
    problem_type = "supervised"

name = f"REFINED"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/{task_type}/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)

# %%
# Determine possible patch sizes for the Vision Transformer by finding divisors of the image width
divisors1 = find_divisors(imgs_shape[1])
divisors1 = [d for d in divisors1  if d >= 16][:-1]
divisors1

# %%
divisors2 = find_divisors(4)
divisors2

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors1=divisors1,
    divisors2=divisors2,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)

# %%
# Get all unique patch sizes tried in the study
patch_sizes = sorted({t.params.get("patch_size") for t in study.trials 
                      if t.state == optuna.trial.TrialState.COMPLETE and "patch_size" in t.params})

# For each patch size, find the best trial and evaluate
for patch in patch_sizes:
    best_trial = max(
        [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE 
         and t.params.get("patch_size") == patch],
        key=lambda t: t.value,
        default=None
    )

    if best_trial is not None:
        print(f"\nEvaluating best trial for patch_size = {patch} (Trial {best_trial.number}, Value: {best_trial.value:.4f})")
        evaluate_best_model(
            best_trial,
            train_loader, val_loader, test_loader,
            dataset_name=dataset_name,
            image_name=name,
            task_type=task_type,
            save_dir=save_dir,
            attributes=attributes,
            imgs_shape=imgs_shape,
            class_weight=class_weight,
            num_classes=num_classes,
            epochs=epochs
        )
    else:
        print(f"No completed trial found for patch_size = {patch}")

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=num_classes,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    divisors1=divisors1,
    divisors2=divisors2,
    attributes=attributes,
    imgs_shape=imgs_shape,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs,
    image_mode='refined_both'
), n_trials=n_trials)

# %%
# Get all unique patch sizes tried in the study
patch_sizes = sorted({t.params.get("patch_size") for t in study.trials 
                      if t.state == optuna.trial.TrialState.COMPLETE and "patch_size" in t.params})

# For each patch size, find the best trial and evaluate
for patch in patch_sizes:
    best_trial = max(
        [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE 
         and t.params.get("patch_size") == patch],
        key=lambda t: t.value,
        default=None
    )

    if best_trial is not None:
        print(f"\nEvaluating best trial for patch_size = {patch} (Trial {best_trial.number}, Value: {best_trial.value:.4f})")
        evaluate_best_model(
            best_trial,
            train_loader, val_loader, test_loader,
            dataset_name=dataset_name,
            image_name=name,
            task_type=task_type,
            save_dir=save_dir,
            attributes=attributes,
            imgs_shape=imgs_shape,
            class_weight=class_weight,
            num_classes=num_classes,
            epochs=epochs,
            image_mode='refined_both'
        )
    else:
        print(f"No completed trial found for patch_size = {patch}")

# %% [markdown]
# ## HyCNN

# %%
save_dir =  os.path.join("logs", task_type, dataset_name)
model_name = "resnet_hybrid"

# Load config
with open(f"./configs/preprocess/{dataset_name}.json") as f:
    config = json.load(f)
batch_size = config["batch_size"]
epochs = config["epochs"]

n_trials = 50

device='cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
def objective(trial, model_name, image_name, task_type, 
              train_loader, val_loader, test_loader, attributes, imgs_shape,
              num_classes=None, device='cuda', save_dir=None, class_weight=None, epochs=100):
    
    task = task_type.lower()
    
    params = load_search_space(model_name, trial)

    params["mlp_hidden_dims"] = json.loads(params["mlp_hidden_dims"])

    params["fusion_hidden_dims"] = json.loads(params["fusion_hidden_dims"])
    
    with open(f"configs/optuna_search/{model_name}.json", "r") as f:
        full_config = json.load(f)

    config = full_config[model_name]["fit"]  # Access the model key

    # Build and train model
    model = ResNetMLP(imgs_shape, attributes, params, task_type=task_type.lower(), num_classes=num_classes)
    metrics = compile_and_fit(
        model,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        model_name=f"trial_{trial.number}",
        image_name=image_name,
        task=task,  # assumed to be defined externally
        max_lr=trial.suggest_float("max_lr", config["max_lr"][1], config["max_lr"][2], log=True),
        div_factor=trial.suggest_int("div_factor", config["div_factor"][1], config["div_factor"][2]),
        final_div_factor=trial.suggest_int("final_div_factor", config["final_div_factor"][1], config["final_div_factor"][2]),
        weight_decay=trial.suggest_float("weight_decay", config["weight_decay"][1], config["weight_decay"][2], log=True),
        epochs=epochs,
        save_model=False,
        class_weights=class_weight
    )

    save_dir = os.path.join(save_dir, model_name, image_name, "optuna")
    os.makedirs(save_dir, exist_ok=True)

    if task == 'regression':
        score = metrics["val_rmse"]
        with open(f"{save_dir}/optuna_trials_log.txt", "a") as f:
            f.write(f"Trial {trial.number} - VAL-RMSE: {score:.4f}, Params: {params}\n")
            f.write("=" * 60 + "\n")
    
    elif task == 'binary':
        score = metrics["val_roc_auc"]
        with open(f"{save_dir}/optuna_trials_log.txt", "a") as f:
            f.write(f"Trial {trial.number} - VAL-AUC: {score:.4f}, Params: {params}\n")
            f.write("=" * 60 + "\n")

    elif task == 'multiclass':
        score = metrics["val_accuracy"]
        with open(f"{save_dir}/optuna_trials_log.txt", "a") as f:
            f.write(f"Trial {trial.number} - VAL-Accuracy: {score:.4f}, Params: {params}\n")
            f.write("=" * 60 + "\n")
    else:
        raise ValueError(f"Unsupported task type: {task_type}")
    
    return score

# %%
def evaluate_best_model(best_trial, train_loader, val_loader, test_loader, 
                        dataset_name, image_name, task_type, save_dir, attributes, imgs_shape, 
                        class_weight=None, num_classes=None, epochs=10):

    task = task_type.lower()
    best_params = best_trial.params

    print(f"\nBest Trial: {best_trial.number}")
    print(f"  Best Score: {best_trial.value:.4f}")
    print("  Best Hyperparameters:")
    for k, v in best_params.items():
        print(f"    {k}: {v}")

    # Extract architecture-related parameters
    architecture_params = {
        k: v for k, v in best_params.items()
        if k in ["mlp_hidden_dims", "fusion_hidden_dims"]
    }

    # Convert JSON string to list if necessary
    if isinstance(architecture_params.get("mlp_hidden_dims"), str):
        architecture_params["mlp_hidden_dims"] = json.loads(architecture_params["mlp_hidden_dims"])
    
    if isinstance(architecture_params.get("fusion_hidden_dims"), str):
        architecture_params["fusion_hidden_dims"] = json.loads(architecture_params["fusion_hidden_dims"])

    # Initialize model
    model = ResNetMLP(imgs_shape, attributes, architecture_params, task_type=task_type.lower(), num_classes=num_classes)

    # Train and evaluate~
    metrics = compile_and_fit(
        model,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=image_name,
        model_name=model_name,
        trial_name=f"trial_{best_trial.number}",
        task=task,
        max_lr=best_params["max_lr"],
        div_factor=best_params["div_factor"],
        final_div_factor=best_params["final_div_factor"],
        weight_decay=best_params["weight_decay"],
        epochs=epochs,
        save_model=True,
        class_weights=class_weight,
        save_dir=save_dir
    )

    # Add training-related fixed params
    best_params["epochs"] = epochs
    best_params["class_weight"] = class_weight.tolist() if class_weight is not None else None    

    # Save best hyperparameters
    params_file = os.path.join(save_dir, f"{model_name}/{image_name}/best_model/trial_{best_trial.number}", "best_params.json")
    os.makedirs(os.path.dirname(params_file), exist_ok=True)

    with open(params_file, "w") as f:
        json.dump(best_params, f, indent=4)

    return metrics

# %% [markdown]
# ### EXPERIMENT: TINTO

# %%
#Select the model and the parameters
problem_type = "supervised"
name = f"TINTO_blur"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/Binary/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=1,
    attributes=attributes,
    imgs_shape=imgs_shape,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)

# %%
# Get the best completed trial
best_trial = max(
    [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE],
    key=lambda t: t.value,
    default=None
)

if best_trial is not None:
    print(f"Evaluating best trial (Trial {best_trial.number}, Value: {best_trial.value:.4f})")
    
    evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=1,
        epochs=epochs
    )
else:
    print("No completed trials found.")

# %% [markdown]
# ### EXPERIMENT: IGTD

# %%
#Select the model and the parameters
problem_type = "supervised"
name = f"IGTD"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/Binary/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=1,
    attributes=attributes,
    imgs_shape=imgs_shape,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)

# %%
# Get the best completed trial
best_trial = max(
    [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE],
    key=lambda t: t.value,
    default=None
)

if best_trial is not None:
    print(f"Evaluating best trial (Trial {best_trial.number}, Value: {best_trial.value:.4f})")
    
    evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=1,
        epochs=epochs
    )
else:
    print("No completed trials found.")

# %% [markdown]
# ### EXPERIMENT: REFINED

# %%
#Select the model and the parameters
problem_type = "supervised"
name = f"REFINED"

#Define the dataset path and the folder where the images will be saved
images_folder = f"SyntheticImages/Binary/{dataset_name}/{name}"

# %%
train_loader, val_loader, test_loader, attributes, imgs_shape, label_encoder, class_weight  = load_and_preprocess_data(df, dataset_name, images_folder, problem_type, task_type, seed=SEED, batch_size=batch_size, device=device)

# %%
import optuna
study = optuna.create_study(direction="minimize" if task_type.lower() == "regression" else "maximize")
study.optimize(lambda trial: objective(
    trial=trial,
    model_name=model_name,
    image_name=name,
    task_type=task_type,
    num_classes=1,
    attributes=attributes,
    imgs_shape=imgs_shape,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    device=device,
    save_dir=save_dir,
    class_weight=class_weight,
    epochs=epochs
), n_trials=n_trials)

# %%
# Get the best completed trial
best_trial = max(
    [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE],
    key=lambda t: t.value,
    default=None
)

if best_trial is not None:
    print(f"Evaluating best trial (Trial {best_trial.number}, Value: {best_trial.value:.4f})")
    
    evaluate_best_model(
        best_trial,
        train_loader, val_loader, test_loader,
        dataset_name=dataset_name,
        image_name=name,
        task_type=task_type,
        save_dir=save_dir,
        attributes=attributes,
        imgs_shape=imgs_shape,
        class_weight=class_weight,
        num_classes=1,
        epochs=epochs
    )
else:
    print("No completed trials found.")
